# %% [markdown]
# <a href="https://colab.research.google.com/github/gomigom1068/YBIGTA_DA/blob/main/%EC%BD%94%EB%A1%9C%EB%82%98_%EB%B0%B0%EB%8B%AC%EB%AC%B8%ED%99%94_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 제목
# ## 부제목
# ### 팀명

# %% [markdown]
# ## 목차
#
# 1. 서론
# 배달 증가~ 뉴스 기사 첨부
#
# 2. 서울/경기 배달 데이터 분석
# 2-1.
# 2-2.
#
# 3. 건강지표 신체/정신/환경
# 3-1. 신체
# 3-2. 정신
# 3-3. 환경
#
# 4. 문제해결방안
# 4-1.신체
# 4-2.정신
# 4-3.환경
#
# 5.부록
# 전처리 및 시각화 코드
# Appendix

# %% [markdown]
# ## 서론
#
# (기사)
# - 야식 증가(https://m.health.chosun.com/svc/news_view.html?contid=2020052903312)
# - 집밥/배달문화 변화(https://www.foodbank.co.kr/news/articleView.html?idxno=59822)

# %% [markdown]
# ## 본문

# %% [markdown]
# ### 코로나 확진자
#
# 배달 데이터 기간(19.12.01~ 20.05.31)의 누적/일별 확진자를 보면, 20년 2월 말에 확진자가 크게 증가한 모습을 확인할 수 있습니다. 이 시점이 우리나라에서 처음으로 대규모 확진자가 발생했던 시기이기 때문에 이 시점 전후로 사람들의 생활문화 변화가 가장 크게 나타날 것이라고 생각했습니다. 그래서 1차유행 정점(20.02.29)를 기준으로 여러 데이터를 비교해보았습니다

# %%
IPython.display.HTML(filename = corona_confirmed.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/shine.js"></script>
#
# </head>
# <body>
#     <div id="c758dcf73c1f4e2a996b27a0b8a3b884" class="chart-container" style="width:800px; height:500px;"></div>
#     <script>
#         var chart_c758dcf73c1f4e2a996b27a0b8a3b884 = echarts.init(
#             document.getElementById('c758dcf73c1f4e2a996b27a0b8a3b884'), 'shine', {renderer: 'canvas'});
#         var option_c758dcf73c1f4e2a996b27a0b8a3b884 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
# ...

# %%
IPython.display.HTML(filename = corona_confirmed1.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/shine.js"></script>
#
# </head>
# <body>
#     <div id="4ea5759033584f36be1f623143279a1c" class="chart-container" style="width:800px; height:500px;"></div>
#     <script>
#         var chart_4ea5759033584f36be1f623143279a1c = echarts.init(
#             document.getElementById('4ea5759033584f36be1f623143279a1c'), 'shine', {renderer: 'canvas'});
#         var option_4ea5759033584f36be1f623143279a1c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
# ...

# %% [markdown]
# ### 지역별 배달 요청 수
#
# 해당 기간동안 배달 요청 수를 기준으로, **서울(구로, 금천, 영등포)**과 **경기(의정부, 부천, 광명)** 각각 **상위 3개** 지역 데이터를 활용해 비교했습니다.
# 서울과 경기 모두 평균 배달 요청 수가 1차 유행 이전보다 1차 유행이후 증가한 것을 확인할 수 있었고, 대규모 확진자 발생의 영향을 받았을 것이라고 생각했습니다.

# %%
IPython.display.HTML(filename = del_seoul_gk_tab.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#         <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
# ...

# %%
IPython.display.HTML(filename = del_seoul_gk_tab_1.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/westeros.js"></script>
#
#
# </head>
# <body>
#         <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
# ...

# %%
IPython.display.HTML(filename = del_seoul_gk_tab_2.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#         <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
# ...

# %% [markdown]
# - 서울, 경기의 일일 확진자 수를 볼 때, 대규모 확진(일 100명 이상) 발생은 없고, 증가/감소를 반복하는 경향
# - 서울(3월 중순경) 구로구 콜센터 집단감염 발생 이후 확진자 큰 폭으로 증가
# - 일일 배달 요청 수도 증가/감소를 반복하는 경향을 보이는 것을 알 수 있음
# - 배달 당일 전후 며칠간의 확진자 수가 당일 배달 요청 수에 영향을 준 것으로 보임

# %%
IPython.display.HTML(filename=del_day_tab.render())

# %% [markdown]
# ### 지역별 야식비율 변화
#
# 배달하면 가장 먼저 떠오르는 것이 치킨, 피자와 같은 **야식**이므로 배달량의 증가가 야식 주문의 증가로 이어졌을 것이라고 예상하고 1차유행 전후의 야식비율을 비교해봤습니다. 그리고 식사시간대의 주문량도 같이 비교해보기 위해 저녁시간에 주문한 수의 비율도 같이 비교해봤습니다.
# - 야식 시간대(저녁 9시~ 새벽4시 사이 주문)
# - 저녁 시간대(오후 5시~ 저녁8시 사이 주문)
# - 데이터상, 야식 비율은 오히려 감소한 모습, 저녁 비율도 큰 변화 없음
# - 이는 상대적으로 낮~오후 시간대에 배달주문한 비율이 늘었다는 것을 의미
# - 코로나로 인해 사람들이 외식을 하기 보다 실내에서 배달 주문을 많이 한 것으로 보임

# %%
IPython.display.HTML(filename = nd_ratio.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#         <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
# ...

# %% [markdown]
# ### 연령대 / 배달금액
#
# 배달앱 사용이 늘어감에 따라 배달문화는 청장년층에게 점점 더 익숙해지고 있습니다. 연령대와 관계가 있는 배달 관련 지표가 배달 금액이라고 생각했습니다. 청장년층은 대학생, 사회초년생들이 대부분이므로 금전적으로 많은 여유가 없을 것입니다. 따라서 1회 배달 시 비싼 음식들을 시켜먹기 힘들 것이고, 평균 배달 금액이 낮을 것이라는 가정 아래 지표를 분석해봤습니다.
#
# - 청장년층(20세~39세 사이)
# - 1차 유행 이후 평균 배달 금액은 증가
# - 서울 지역중 영등포구, 경기 지역중 부천시가 청장년층의 비율이 가장 높았고, 평균 배달 금액이 나타남
# - 성인의 경우, 나이와 평균 배달 금액이 반비례하는 경향을 보이는 것을 알 수 있었음

# %%
IPython.display.HTML(filename = region_ratio_1.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#         <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
# ...

# %%
IPython.display.HTML(filename = del_seoul_gk_money.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#         <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
# ...

# %%
IPython.display.HTML(filename = del_seoul_gk_money_1.render())

# %%
IPython.display.HTML(filename = del_menu.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#         <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
# ...

# %% [markdown]
# ### 배달 시간
#
# 바이브의 분석결과를 통해, SNS상에서 소비자들이 배달과 관련해 가장 많이 사용한 표현은 **'빠르다'**로 전년보다 사용 빈도가 **48.2%** 늘어난 것을 확인할 수 있었습니다. 이는 '맛있다'라는 표현의 사용 빈도 증가율(38.8%) 보다 크게 높습니다.
# 따라서, 소비자들의 배달과 관련된 주요 관심사가 속도라는 것을 알 수 있습니다.
# 그래서 지역별로 평균 배달 시간 비교를 해보기로 했습니다.
#
# - 1차 유행 전/후를 비교해 봤을 때 평균 배달 시간이 약1~2분정도 감소함
# - 이는 코로나 이후 배달량이 증가하며 배달 속도 경쟁도 치열해졌다는 것을 의미

# %%
IPython.display.HTML(filename = del_time.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#         <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
# ...

# %%
IPython.display.HTML(filename = del_time_1.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#         <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
# ...

# %%
IPython.display.HTML(filename = fig_store.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#     <style>.box { justify-content:center; display:flex; flex-wrap:wrap;  }; </style>
#     <div class="box">
#                 <div id="7885525c12474ff2b2f66bea03cc1b2c" class="chart-container" style="width:1000px; height:500px;"></div>
#     <script>
#         var chart_7885525c12474ff2b2f66bea03cc1b2c = echarts.init(
#             document.getElementById('7885525c12474ff2b2f66bea03cc1b2c'), 'roma', {renderer: 'canvas'});
#         var option_7885525c12474ff2b2f66bea03cc1b2c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
# ...

# %%
IPython.display.HTML(filename = fig_n_1.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#     <style>.box { justify-content:center; display:flex; flex-wrap:wrap;  }; </style>
#     <div class="box">
#                 <div id="9e4cddb7771d4a558e32032834885722" class="chart-container" style="width:1000px; height:500px;"></div>
#     <script>
#         var chart_9e4cddb7771d4a558e32032834885722 = echarts.init(
#             document.getElementById('9e4cddb7771d4a558e32032834885722'), 'roma', {renderer: 'canvas'});
#         var option_9e4cddb7771d4a558e32032834885722 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
# ...

# %%
IPython.display.HTML(filename = fig_n_2.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#     <style>.box { justify-content:center; display:flex; flex-wrap:wrap;  }; </style>
#     <div class="box">
#                 <div id="2834c117352345b29cceefc91ec0f9f8" class="chart-container" style="width:300px; height:300px;"></div>
#     <script>
#         var chart_2834c117352345b29cceefc91ec0f9f8 = echarts.init(
#             document.getElementById('2834c117352345b29cceefc91ec0f9f8'), 'roma', {renderer: 'canvas'});
#         var option_2834c117352345b29cceefc91ec0f9f8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
# ...

# %%
IPython.display.HTML(filename = fig_time.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#     <style>.box { justify-content:center; display:flex; flex-wrap:wrap;  }; </style>
#     <div class="box">
#                 <div id="4f226887c24d4ee0b4f04705d85ea222" class="chart-container" style="width:1000px; height:500px;"></div>
#     <script>
#         var chart_4f226887c24d4ee0b4f04705d85ea222 = echarts.init(
#             document.getElementById('4f226887c24d4ee0b4f04705d85ea222'), 'roma', {renderer: 'canvas'});
#         var option_4f226887c24d4ee0b4f04705d85ea222 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
# ...

# %%
IPython.display.HTML(filename = fig_s_week.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
# </head>
# <body>
#     <div id="4fd8d83e80e24b68b145c984d12fd816" class="chart-container" style="width:800px; height:500px;"></div>
#     <script>
#         var chart_4fd8d83e80e24b68b145c984d12fd816 = echarts.init(
#             document.getElementById('4fd8d83e80e24b68b145c984d12fd816'), 'roma', {renderer: 'canvas'});
#         var option_4fd8d83e80e24b68b145c984d12fd816 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "clockwise": true,
#                 "data": [
#                     {
#                         "name": "\uc6d4\uc694\uc77c",
#                         "value": 54999
# ...

# %%
IPython.display.HTML(filename = fig_g_week.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="b697d085ddfc4bbb837f509a30539197" class="chart-container" style="width:800px; height:500px;"></div>
#     <script>
#         var chart_b697d085ddfc4bbb837f509a30539197 = echarts.init(
#             document.getElementById('b697d085ddfc4bbb837f509a30539197'), 'white', {renderer: 'canvas'});
#         var option_b697d085ddfc4bbb837f509a30539197 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "clockwise": true,
#                 "data": [
#                     {
#                         "name": "\uc6d4\uc694\uc77c",
#                         "value": 190890
#                     },
#                     {
#                         "name": "\ud654\uc694\uc77c",
# ...

# %%
IPython.display.HTML(filename = salad_bar.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
# </head>
# <body>
#     <div id="5a98312294f7493aa528d972a5e6bd93" class="chart-container" style="width:800px; height:400px;"></div>
#     <script>
#         var chart_5a98312294f7493aa528d972a5e6bd93 = echarts.init(
#             document.getElementById('5a98312294f7493aa528d972a5e6bd93'), 'roma', {renderer: 'canvas'});
#         var option_5a98312294f7493aa528d972a5e6bd93 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
# ...

# %% [markdown]
# ### 육체건강
#
# 코로나가 사람들의 생활방식을 크게 변화시켰고, 사람들의 라이프스타일은 외부 활동 중심에서 비대면 방식의 언택트(Untact) 소비, 활동으로 변화했습니다. 줄어든 활동량, 늘어난 배달 주문 수는 건강에 악영향을 미쳤을 것이라고 생각했습니다. 2020년 질병관리본부의 지역사회건강조사의 데이터를 기반으로 사람들의 건강관련 지표를 분석해봤습니다.
# 전체적으로, 좋은 지표는 줄어들고, 나쁜 지표는 증가한 것을 확인할 수 있었습니다.
# 2019년과 2020년의 증감 폭이 가장 컸고, 코로나에 많은 영향을 받았음을 알 수 있었습니다.
#
# - 사람들의 줄어든 활동량이 걷기 실천율, 건강생활 실천율의 감소로 이어졌고, 비만율, 체중조절 시도율의 증가로 이어짐
# - 체중조절 시도율의 증가는 사람들이 이전과 비교해 자신의 몸상태가 좋지 못하다고 인식하는 비율이 늘었다는 것을 의미한다고 유추해볼 수 있음

# %%
IPython.display.HTML(filename= health_tab.render())

# %% [markdown]
# ### 정신건강

# %%
IPython.display.HTML(filename = fig_psy_tab.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/shine.js"></script>
#
#
# </head>
# <body>
#         <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
# ...

# %%
IPython.display.HTML(filename = fig_psy_2_tab.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#         <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
# ...

# %%
IPython.display.HTML(filename = fig_psy_3_tab.render())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#         <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
# ...

# %% [markdown]
# ### 서연 파트

# %% [markdown]
# #### 네이버 크롤링 데이터
# 저희는 배달 데이터 이외에도 코로나 이후 국민들의 식문화 변화를 파악해보고자 네이버 데이터랩 API를 사용하였습니다. 또한 대회에서 제공되는 데이터는 기간이 2019년 12월부터 2020년 5월까지인데 반해, 네이버 API는 최근까지 크롤링할 수 있기 때문에 데이터의 계절성을 분석하기에도 적합하다고 판단하였습니다. <br>
# 쇼핑몰에 검색 및 조회 비중이 높을수록 대중의 관심이 많은 품목일 것이라고 가정한 후 2019년 1월부터 2021년 8월까지의 네이버 쇼핑 내 식품 조회수를 살펴보았는데요, 그 결과 가공식품, 음료, 건강식품, 다이어트식품, 간편조리식이 상위권을 차지하는 것을 확인했습니다. <br>
#
# 그 중에서 약품의 성격이 짙은 건강식품과 다이어트식품을 제외하고 식생활과 직접적인 관련이 있는 나머지 카테고리에 대해 세부 품목에 대한 조회수를 확인해보았습니다. <br>
#
# 가공식품
# * 가공식품 그래프를 보면 즉석밥과 간편조리식이 월등히 높은 지점이 있는데요, 각각 2/24, 25의 수치인 것으로 보아 저희가 1차 유행 기준점으로 잡은 2/29와 매우 근접했습니다. 따라서 집단 확산으로 인해 불안감을 느낀 국민들이 외식을 줄이고자 즉석식품을 구매했다고 유추해볼 수 있었습니다.
# * 2019년 내내 저조한 조회수를 기록하던 쿠킹박스가 2020년 9월 이후로 점차 상승하다가 12월 21일에 최고치를 달성한 후 2019년보다는 확연히 상승한 조회수를 보입니다. 흥미로운 점은 2019년도 최고치 역시 인접한 12월 23일자였습니다. 크리스마스 기간이라 요리하기가 번거로웠던걸까요? 🤔
#
# 음료
# * 코로나로 인해 '홈카페'를 즐기는 사람이 많아진 만큼, 커피에 대한 수요가 얼마나 변화했는지 알아보았습니다. 커피와 원두 모두 2019년에 비해 **2020년에 급격하게 증가**했지만, 저희가 설정한 1차 유행 기간에는 큰 변화가 없었던 것으로 보아, 커피는 생필품이 아니다보니 다른 품목에 비해 관심이 적었던 것이 아닐까 하고 예상했습니다.
# * 캡슐커피의 경우 2021년 1월 17일 이후부터 데이터가 크롤링되었는데요, 일반커피보다 높은 조회수를 보이는 것을 보니 현재 대한민국은 '캡슐커피'에 주목하고 있는 것으로 보입니다.
#
# 간편조리
# * 간편조리식품 중에서 주목할 것은 즉석국/즉석탕인데요, 2/25에 급상한 것으로 보아 가공식품의 경우와 마찬가지로 **1차 유행의 영향이 컸다**고 볼 수 있을 것 같습니다.
# * '샐러드'의 조회수를 통해 건강 및 체중 감량에 대한 사람들의 관심도를 알아보고자 했는데, 의외로 샐러드는 2019년과 비교했을 때 큰 변화를 보이지 않았습니다.
#
# 가전
# *   집에 있는 시간이 길어져 집에서 요리하는 횟수가 증가했다는 보도가 많은데요, 저희는 이를 통해 식품 소비 이외에도 주방 가전 및 용품에 대한 관심도가 증가했을 것으로 예상해보았습니다. 네이버 쇼핑 내에서 주방용품과 주방가전, 그리고 생활가전에 대한 조회수를 살펴보니, 2019년과 큰 차이를 보이지 않는 생활가전에 비해 주방용품과 주방가전은 급격한 상승세를 보였습니다.
# * 음식물처리기의 경우 2020년 5월, 6월의 조회수가 눈에 띕니다. 그만큼 사람들이 코로나로 인해 집에서 식사하는 빈도가 잦아 늘어난 음식물을 처리하기가 난감해졌다는 뜻이겠죠? 이는 후술할 환경 문제와도 연결됩니다.
#
# 닭가슴살
#
# * 한편 흥미로운 사실은 식품 전체 인기 검색어에서 ‘닭가슴살’이 매우 높은 순위에 자리하고 있다는 점이었습니다. 닭가슴살은 체중 감량 등 다이어트를 위해 주로 섭취를 하다보니, 저희는 이 점이 코로나의 영향을 받은 결과일지 궁금해졌습니다. **코로나로 인해 운동은 덜 하고 집에만 있게 되어 체중이 늘었다**는 이야기는 많이 들었지만, 과연 닭가슴살의 높은 순위도 그 영향을 받았을지 알아보고자 2019년과 2020, 2021년의 검색 조회수를 살펴보았습니다.
#
# *   예상대로 닭가슴살의 높은 조회량은 코로나로 인한 체중 증가에 기인했음을 확인할 수 있었습니다. 최대 50, 평균 32의 조회수를 보였던 2019년과 달리, 2020년과 2021년에서는 **평균적으로는 47의 조회수**를 보였고, 심지어는 **최대치인 100**까지 도달하였습니다.
# * 따라서 코로나의 여파로 **다이어트에 대한 수요가 증가**하였고, 이를 입증하듯 닭가슴살 검색 빈도수도 덩달아 올라갔다는 결론을 내렸습니다.

# %% [markdown]
# #### 환경
# 앞서 확인한 네이버 그래프에서 음식물처리기에 대한 조회가 코로나 이후로 급상승세를 보였는데, 집에서 식사하는 경우가 증가한 만큼 음식물 쓰레기 처리에 대한 고민도 덩달아 늘었을 것으로 예상할 수 있습니다. <br>
# 음식물 쓰레기 뿐만 아니라, 배달 증가와 위생 문제로 인한 무분별한 일회용품 사용 역시 코로나 여파의 심각한 문제로 대두되고 있죠. 이에 따라 환경 데이터 역시 살펴보았습니다.
# <br>
# ※ 폐기물 및 재활용에 관한 오픈 데이터가 2019년 이후로 존재하지 않아, 통계청에서 공식으로 보도한 문서를 바탕으로 작성하였습니다.
# <br>
# ![택배](./DATA/택배.png)
# *   온라인 쇼핑이 증가하는 추세에 더해, 코로나 19의 여파로 택배 물류량이 이전 연도 동월과 대비하여 평균적으로 **30%** 가량 증가하였습니다. 택배 역시 일회용품을 많이 필요로 하죠. 물류량이 증가한만큼 일회용품 폐기물도 증가했을 것으로 예상됩니다. 더군다나 최근 온라인 배송 서비스 업체들의 과대포장이 문제로 이슈된 바 있습니다.
#
# ![컵](./DATA/컵.png)
# *   그렇다면 1회용 컵, 나무젓가락 등 일회용 식기의 경우 어떨까요? 2018년부터 매장 내 1회용 컵을 줄이기 위한 일환으로 플라스틱 컵을 사용하지 못하는 제도가 생겼는데요, 코로나의 확산으로 감염이 우려되어 1회용 컵 사용을 한시적으로 허용하였습니다 . 이로 인해 종이와 플라스틱 컵의 사용이 전년 대비 **30%** 가량 늘어났다고 합니다.
#
# ![재활용](./DATA/재활용.png)
# * 가정에서 나오는 생활폐기물의 경우, 2009년부터 꾸준히 증가해왔습니다. 이와 더불어 코로나 발생 이후 재활용 가능 품목의 발생량이 약 10% 증가하였는데, 이 중 플라스틱과 종이가 가장 크게 증가하였다고 합니다. 코로나 발생 이후 늘어난 배달과 택배의 포장재로 인한 것으로 추측됩니다.

# %% [markdown]
# ## 결론

# %% [markdown]
# #### 육체건강
#
# 코로나 이후 줄어든 활동량은 우리 몸의 건강에 안 좋은 영향을 미치게 되었습니다. 하지만 운동 시설의 영업시간 제한, 코로나 감염 위험 등으로 이전 보다 건강 관리가 쉽지 않습니다😥
# 그러면 Untact 방식으로 진행해보는 건 어떨까요?
#
# - 코로나 시대 배달 산업의 성장과 함께 큰 성장을 보여준 산업이 1인 미디어 산업(ex.유튜브)입니다. 코로나로 인해 사람들의 홈트레이닝에 대한 관심이 높아졌고, 많은 유튜버, BJ들이 관련 컨텐츠를 좋은 퀄리티로 제공하고 있습니다. 본인이 홈트레이닝을 하고 싶은데, 어떻게 시작해야할지 방법을 모르시겠다면 유튜브의 홈트레이닝 관련 동영상을 참고해서 시작해보면 좋을 것 같습니다!💪
# - 만약 홈트레이닝이 어렵고, 하기 힘들다면 한적한 저녁 시간대에 30분 정도 산책을 해보는 건 어떨까요? 하루에 30분정도만 한다면, 낮에 부족했던 활동량도 보완해줄 수 있고, 우리의 답답한 마음도 조금은 풀 수 있을 것 같습니다!
#
# 저희는 이렇게 두 가지 방법을 제안드렸는데, 좀 더 좋은 방법도 많을 것이라고 생각합니다. 다양한 방법을 활용해 건강을 유지하며 맛있는 음식을 즐겼으면 좋겠습니다

# %% [markdown]
# ####환경
# 코로나로 인하여 증가한 음식물 쓰레기와 일회용품을 어떻게 하면 줄여나갈 수 있을까요? 저희 팀은 몇가지 방안을 제안하고 싶습니다.
# * 먼저 정부와 배달/택배 서비스 기업들이 협업하여 일회용품을 줄이되 코로나 감염을 우려하지 않을 수 있는 방안을 모색해야 할 것입니다. 포장재를 최소화하고, 친환경 소재를 쓰는 등의 방법이 있습니다. 실제로 옥수수, 대나무 등 쉽게 분해가 가능한 소재로 만든 용기들이 다수 개발되고 있는데요, 이를 활용해도 좋겠습니다.
# * 배달앱의 경우 일회용품을 필요로 하지 않는다는 항목을 주문자가 체크할 수 있는데요, 이에도 불구하고 무분별하게 일회용품이 배달오고 마는 경우가 많습니다. 요청대로 일회용품을 배달하지 않고, 사용을 최소화하는 업체들에게 배달 서비스 기업들이 인센티브를 주어 환경 보호를 독려하는 방안도 있겠죠.
# <br>
# [생분해 배달용기, 종이가구…죄책감 덜어낸 ‘가치 소비’ 통했다](https://www.hani.co.kr/arti/area/capital/1006381.html)
#
# * 마지막으로는 배달을 시키고, 택배를 받는 소비자들이 포장재를 올바르게 재활용하고 친환경 소재의 제품들에 관심을 가지는 방법입니다. 소비자들의 수요가 많아질수록, 친환경적인 포장을 하는 업체들도 점점 많아질 것입니다.

# %% [markdown]
# ## 부록

# %% [markdown]
# ####참고문헌
# * 무분별한 일회용기 사용에 대한 국민들의 인식
# https://www.hankookilbo.com/News/Read/A2021080911470001044?did=NA
# * 친환경 소재 기업
# https://www.hani.co.kr/arti/area/capital/1006381.html

# %% [markdown]
# ### 전처리 및 시각화 코드

# %%
# !pip install chart_studio
# !pip install pyecharts
# !pip install echarts-themes-pypkg
# !pip install pyechart
# Out:
# ...
#      |████████████████████████████████| 64 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 135 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 129 kB 23.4 MB/s
# ...
#   Using cached pyecharts_jupyter_installer-0.0.3-py2.py3-none-any.whl (4.7 kB)
# ...
#   Created wheel for echarts-themes-pypkg: filename=echarts_themes_pypkg-0.0.3-py3-none-any.whl size=18885 sha256=460f2b01427a41739e575bb333150a6991b0a818ea58854d7905d1c42dde5a21
#   Stored in directory: /root/.cache/pip/wheels/2f/19/ec/9b1dcbee8e87fe66f158fd65755c5a08720a8e53d6811a30b8
# Successfully built echarts-themes-pypkg
# ...
# ERROR: Could not find a version that satisfies the requirement pyechart (from versions: none)
# ERROR: No matching distribution found for pyechart

# %%
import numpy as np
import pandas as pd
import datetime as dt

import json
import folium
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots

from pyecharts.globals import ThemeType
from pyecharts.commons.utils import JsCode
from pyecharts.charts import Bar, Bar3D, Grid, Line, Liquid, Page, Pie, Timeline, Tab
from pyecharts import options as opts
import folium, webbrowser, IPython, warnings
from IPython.display import IFrame

import warnings
warnings.filterwarnings(action='ignore')
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/제목없는 폴더'
# Out:
# /content/drive/MyDrive/제목없는 폴더

# %% [markdown]
# # **종현님**

# %% [markdown]
# #### 배달/인구 데이터 전처리

# %%
# 배달 호출 데이터
d1 = pd.read_csv("./dlvr_call.csv", low_memory=False)

# %%
d1.head()
# Out:
#         SN  PROCESS_DT DLVR_REQUST_ENTRPS_ID  DLVR_REQUST_STTUS_VALUE  \
# 0  3486929  2019-12-01               C000101                        1
# 1  3486930  2019-12-01               C000099                        1
# 2  3486932  2019-12-01               C000029                        1
# 3  3486933  2019-12-01               C000105                        1
# 4  3486934  2019-12-01               C000028                        1
#
#   DLVR_RCEPT_ENTRPS_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# 0              C000101      S0021950                족발/보쌈
# 1              C000099      S0039210                   치킨
# 2              C000043      S0036135                   치킨
# 3              C000105      S0039956               돈까스/일식
# 4              C000043      S0003074                   치킨
#
#    DLVR_STORE_LEGALDONG_CODE DLVR_STORE_BRTC_NM DLVR_STORE_SIGNGU_NM  \
# 0                 1156013200              서울특별시                 영등포구
# ...

# %%
d1.isnull().sum()

# %%
# 지역, 상점 코드 제거
delv = d1.drop(['DLVR_STORE_LEGALDONG_CODE',
               'DLVR_STORE_RDNMADR_CODE','DLVR_DSTN_LEGALDONG_CODE',
               'DLVR_DSTN_RDNMADR_CODE'], axis=1)

# 배달 완료만 사용
delv = delv[delv['DLVR_REQUST_STTUS_VALUE'] == 1]

# 칼럼명 변경
delv.columns = ['순번', '날짜', '배달요청업체_ID', '배달상태', '배달접수업체_ID', '배달상점_ID',
               '업종명','시도명','시군구명','읍면동명','리명','상점_행정동코드','목적지_시도명','목적지_시군구명','목적지_읍면동명','목적지_리명',
               '목적지_행정동코드','기사번호','서비스금액','중계수수료금액','상품금액','결제종류','카드종류','접수시간','배차시간',
               '수령시간','완료시간','취소시간']

# 시간 데이터 전처리
delv['날짜'] = pd.to_datetime(delv['날짜'])
delv['접수시간'] = pd.to_datetime(delv['접수시간'])

delv['배달 접수 시간'] = delv['접수시간'].apply(lambda x: x.hour)
delv['배달 접수 요일'] = delv['접수시간'].dt.weekday
delv['배달 접수 평일/주말'] = delv['배달 접수 요일'].apply(lambda x: '주말' if (x == 5)|(x == 6)
                                                                                         else '평일')

# %%
# 서울 / 경기도 배달 데이터
del_seoul = delv[delv['목적지_시도명']=='서울특별시']
del_gk = delv[delv['목적지_시도명']=='경기도']

# %%
# 인구 데이터 (서울)
d2 = pd.read_csv("./popl.csv")
code = pd.read_csv('./DATA/행정동코드.csv')

code['adstrd_code'] = code['adstrd_code']/100
region_seoul = pd.merge(d2, code, how='left', on='adstrd_code')
region_seoul['base_ymd'] = pd.to_datetime(region_seoul['base_ymd'], format='%Y%m%d')

# 2020-02 ~ 2020-05 데이터만 사용
region_seoul = region_seoul[region_seoul['base_ymd'].dt.month <= 5 ]
region_seoul.reset_index(drop=True, inplace=True)

# 성별이 '-' 인 데이터 제거
region_seoul = region_seoul[region_seoul.sexdstn_se_code != '-']
region_seoul.reset_index(drop=True, inplace=True)

# %%
display(d2.head())
display(code.head())
# Out:
#    base_ymd  ori_table tmzon_se_code sexdstn_se_code  agrde_se_code  \
# 0  20200212          2             F          age_50       11110515
# 1  20200212          2             F          age_15       11110515
# 2  20200212         21             F          age_10       11110515
# 3  20200212          7             F          age_10       11110515
# 4  20200212         16             M          age_25       11110515
#
#    adstrd_code  local_pop  fore_pop_1  fore_pop_2
# 0          205          0           0         NaN
# 1           78          0           0         NaN
# 2           28          0           0         NaN
# 3           49          0           0         NaN
# 4          291          0           0         NaN
#    adstrd_code    시도명 시군구명   읍면동명
# 0   11000000.0  서울특별시  NaN    NaN
# 1   11110000.0  서울특별시  종로구    NaN
# 2   11110515.0  서울특별시  종로구  청운효자동
# 3   11110530.0  서울특별시  종로구    사직동
# 4   11110540.0  서울특별시  종로구    삼청동

# %%
# 인구 데이터 (경기)
region_gk = pd.read_csv('./DATA/지역별_인구.csv') # 2019.12~ 2020.05
region_gk_age = pd.read_csv('./DATA/연령별인구.csv') # 2019.12

region_gk = region_gk[['시군구명', '일자', '전체', '내국인_전체', '내국인_남', '내국인_여', '외국인']]

# %%
# 서울/경기 배달수 top3 데이터 사용
# 서울(구로, 금천, 영등포), 경기(의정부, 부천, 광명)

# top3 서울/경기(배달)
del_seoul_top = del_seoul[(del_seoul['목적지_시군구명']=='구로구') 
                          | (del_seoul['목적지_시군구명']=='금천구') 
                          | (del_seoul['목적지_시군구명']=='영등포구')]

del_gk_top = del_gk[(del_gk['목적지_시군구명']=='의정부시') 
                    | (del_gk['목적지_시군구명']=='부천시') 
                    | (del_gk['목적지_시군구명']=='광명시')]

# top3 서울/경기(인구)
region_seoul_top = region_seoul[(region_seoul['시군구명']=='구로구') 
                                | (region_seoul['시군구명']=='금천구') 
                                | (region_seoul['시군구명']=='영등포구')]

region_gk_top = region_gk[(region_gk['시군구명']=='의정부시') 
                          | (region_gk['시군구명']=='부천시') 
                          | (region_gk['시군구명']=='광명시')]

region_gk_age_top = region_gk_age[(region_gk_age['시군구명']=='의정부시') 
                          | (region_gk_age['시군구명']=='부천시') 
                          | (region_gk_age['시군구명']=='광명시')]

# %%
del_seoul_top.reset_index(drop=True, inplace=True)
del_gk_top.reset_index(drop=True, inplace=True)

# %%
# 1차 유행 이전/ 이후 (배달)
del_seoul_top_bef = del_seoul_top[del_seoul_top['날짜']<='2020-02-28']
del_seoul_top_af = del_seoul_top[del_seoul_top['날짜']>'2020-02-28']

del_gk_top_bef = del_gk_top[del_gk_top['날짜']<='2020-02-28']
del_gk_top_af = del_gk_top[del_gk_top['날짜']>'2020-02-28']

del_seoul_top_af.reset_index(drop=True, inplace=True)
del_gk_top_af.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### 배달 요청 수

# %%
# 1차 유행 이전/이후 배달 요청 수(서울/경기)

del_seoul_top_bef_count = pd.DataFrame(del_seoul_top_bef['목적지_시군구명'].value_counts())
del_seoul_top_af_count = pd.DataFrame(del_seoul_top_af['목적지_시군구명'].value_counts())

del_gk_top_bef_count = pd.DataFrame(del_gk_top_bef['목적지_시군구명'].value_counts())
del_gk_top_af_count = pd.DataFrame(del_gk_top_af['목적지_시군구명'].value_counts())

# %%
# 1차 유행 이전/이후 배달 요청 수(서울/경기) + 읍면동

del_seoul_top_bef_count2 = pd.DataFrame(del_seoul_top_bef.groupby('목적지_시군구명')['목적지_읍면동명'].value_counts())
del_seoul_top_af_count2 = pd.DataFrame(del_seoul_top_af.groupby('목적지_시군구명')['목적지_읍면동명'].value_counts())
del_gk_top_bef_count2 = pd.DataFrame(del_gk_top_bef.groupby('목적지_시군구명')['목적지_읍면동명'].value_counts())
del_gk_top_af_count2 = pd.DataFrame(del_gk_top_af.groupby('목적지_시군구명')['목적지_읍면동명'].value_counts())

del_seoul_top_bef_count2.columns = ['수']
del_seoul_top_af_count2.columns = ['수']
del_gk_top_bef_count2.columns = ['수']
del_gk_top_af_count2.columns = ['수']

del_seoul_top_bef_count2.reset_index(drop=False, inplace=True)
del_seoul_top_af_count2.reset_index(drop=False, inplace=True)
del_gk_top_bef_count2.reset_index(drop=False, inplace=True)
del_gk_top_af_count2.reset_index(drop=False, inplace=True)

# %%
# 1차유행 이전/이후 업종별 배달 요청수

del_seoul_menu_bef = pd.DataFrame(del_seoul_top_bef.groupby('목적지_시군구명')['업종명'].value_counts())
del_seoul_menu_af = pd.DataFrame(del_seoul_top_af.groupby('목적지_시군구명')['업종명'].value_counts())
del_gk_menu_bef = pd.DataFrame(del_gk_top_bef.groupby('목적지_시군구명')['업종명'].value_counts())
del_gk_menu_af = pd.DataFrame(del_gk_top_af.groupby('목적지_시군구명')['업종명'].value_counts())

del_seoul_menu_bef.columns = ['수']
del_seoul_menu_af.columns = ['수']
del_gk_menu_bef.columns = ['수']
del_gk_menu_af.columns = ['수']

del_seoul_menu_bef.reset_index(drop=False, inplace=True)
del_seoul_menu_af.reset_index(drop=False, inplace=True)
del_gk_menu_bef.reset_index(drop=False, inplace=True)
del_gk_menu_af.reset_index(drop=False, inplace=True)

# %%
# 1차유행 이전/이후 지역(읍면동),날짜, 업종별 배달 요청수

del_seoul_day_bef = pd.DataFrame(del_seoul_top_bef.groupby(['날짜','목적지_시군구명'])['업종명'].value_counts())
del_seoul_day_af = pd.DataFrame(del_seoul_top_af.groupby(['날짜','목적지_시군구명'])['업종명'].value_counts())
del_gk_day_bef = pd.DataFrame(del_gk_top_bef.groupby(['날짜','목적지_시군구명'])['업종명'].value_counts())
del_gk_day_af = pd.DataFrame(del_gk_top_af.groupby(['날짜','목적지_시군구명'])['업종명'].value_counts())

del_seoul_day_bef.columns = ['수']
del_seoul_day_af.columns = ['수']
del_gk_day_bef.columns = ['수']
del_gk_day_af.columns = ['수']

del_seoul_day_bef.reset_index(drop=False, inplace=True)
del_seoul_day_af.reset_index(drop=False, inplace=True)
del_gk_day_bef.reset_index(drop=False, inplace=True)
del_gk_day_af.reset_index(drop=False, inplace=True)

# %%
# 일별 배달 요청 수

del_seoul_day = pd.DataFrame(del_seoul_top.groupby('날짜')['목적지_시군구명'].value_counts())
del_gk_day = pd.DataFrame(del_gk_top.groupby('날짜')['목적지_시군구명'].value_counts())

del_seoul_day.columns = ['수']
del_gk_day.columns =['수']

del_seoul_day.reset_index(drop=False, inplace=True)
del_gk_day.reset_index(drop=False, inplace=True)

# %%
# 일별 업종별 배달 요청 수

del_seoul_day_menu = pd.DataFrame(del_seoul_top.groupby(['날짜', '목적지_시군구명'])['업종명'].value_counts())
del_gk_day_menu = pd.DataFrame(del_gk_top.groupby(['날짜', '목적지_시군구명'])['업종명'].value_counts())

del_seoul_day_menu.columns = ['수']
del_gk_day_menu.columns =['수']

del_seoul_day_menu.reset_index(drop=False, inplace=True)
del_gk_day_menu.reset_index(drop=False, inplace=True)

# %%
# 1차유행 이전/이후 야식 비율

del_seoul_top_bef['접수시간'] = pd.to_datetime(del_seoul_top_bef['접수시간'])
del_seoul_top_af['접수시간'] = pd.to_datetime(del_seoul_top_af['접수시간'])
del_gk_top_bef['접수시간'] = pd.to_datetime(del_gk_top_bef['접수시간'])
del_gk_top_af['접수시간'] = pd.to_datetime(del_gk_top_af['접수시간'])

# 21시 이후~ 04시 이전
del_seoul_top_bef_night = pd.DataFrame(del_seoul_top_bef[(del_seoul_top_bef['접수시간'].dt.hour >= 21)
                                                        | (del_seoul_top_bef['접수시간'].dt.hour <= 4)]['목적지_시군구명'].value_counts())
del_seoul_top_af_night = pd.DataFrame(del_seoul_top_af[(del_seoul_top_af['접수시간'].dt.hour >= 21)
                                                        | (del_seoul_top_af['접수시간'].dt.hour <= 4)]['목적지_시군구명'].value_counts())
del_gk_top_bef_night = pd.DataFrame(del_gk_top_bef[(del_gk_top_bef['접수시간'].dt.hour >= 21)
                                                        | (del_gk_top_bef['접수시간'].dt.hour <= 4)]['목적지_시군구명'].value_counts())
del_gk_top_af_night = pd.DataFrame(del_gk_top_af[(del_gk_top_af['접수시간'].dt.hour >= 21)
                                                        | (del_gk_top_af['접수시간'].dt.hour <= 4)]['목적지_시군구명'].value_counts())


# 비율

del_seoul_top_bef_nr = del_seoul_top_bef_night['목적지_시군구명'] / del_seoul_top_bef_count['목적지_시군구명']
del_seoul_top_af_nr = del_seoul_top_af_night['목적지_시군구명'] / del_seoul_top_af_count['목적지_시군구명']
del_gk_top_bef_nr = del_gk_top_bef_night['목적지_시군구명'] / del_gk_top_bef_count['목적지_시군구명']
del_gk_top_af_nr = del_gk_top_af_night['목적지_시군구명'] / del_gk_top_af_count['목적지_시군구명']

# %%
# 1차유행 이전/이후 저녁 비율


# 17시 이후~ 20시 이전
del_seoul_top_bef_din = pd.DataFrame(del_seoul_top_bef[(del_seoul_top_bef['접수시간'].dt.hour <= 20)
                                                        & (del_seoul_top_bef['접수시간'].dt.hour >= 17)]['목적지_시군구명'].value_counts())
del_seoul_top_af_din = pd.DataFrame(del_seoul_top_af[(del_seoul_top_af['접수시간'].dt.hour <= 20)
                                                        & (del_seoul_top_af['접수시간'].dt.hour >= 17)]['목적지_시군구명'].value_counts())
del_gk_top_bef_din = pd.DataFrame(del_gk_top_bef[(del_gk_top_bef['접수시간'].dt.hour <= 20)
                                                        & (del_gk_top_bef['접수시간'].dt.hour >= 17)]['목적지_시군구명'].value_counts())
del_gk_top_af_din = pd.DataFrame(del_gk_top_bef[(del_gk_top_af['접수시간'].dt.hour <= 20)
                                                        & (del_gk_top_af['접수시간'].dt.hour >= 17)]['목적지_시군구명'].value_counts())

# 비율

del_seoul_top_bef_dinr = del_seoul_top_bef_din['목적지_시군구명'] / del_seoul_top_bef_count['목적지_시군구명']
del_seoul_top_af_dinr = del_seoul_top_af_din['목적지_시군구명'] / del_seoul_top_af_count['목적지_시군구명']
del_gk_top_bef_dinr = del_gk_top_bef_din['목적지_시군구명'] / del_gk_top_bef_count['목적지_시군구명']
del_gk_top_af_dinr = del_gk_top_af_din['목적지_시군구명'] / del_gk_top_af_count['목적지_시군구명']

# %% [markdown]
# #### 인구 수

# %%
# 서울 지역(구, 읍면동)/나이/성별 평균 인구수

region_seoul_top_mean = pd.DataFrame(region_seoul_top.groupby(['시군구명','읍면동명','agrde_se_code','sexdstn_se_code'])['local_pop'].mean())
region_seoul_top_mean.reset_index(drop=False, inplace=True)

# 경기 지역/성별 평균 인구수

region_gk_top_mean = pd.DataFrame(region_gk_age_top.groupby(['시군구명','연령'])[['전체','남','여']].mean())
region_gk_top_mean.reset_index(drop=False, inplace=True)

# %%
# 서울 지역 청장년층 인구수

region_seoul_top_young = region_seoul_top_mean[(region_seoul_top_mean['agrde_se_code']=='age_20')
                                              | (region_seoul_top_mean['agrde_se_code']=='age_25')
                                              | (region_seoul_top_mean['agrde_se_code']=='age_30')
                                              | (region_seoul_top_mean['agrde_se_code']=='age_35')]
region_seoul_top_young = pd.DataFrame(region_seoul_top_young.groupby(['시군구명','읍면동명'])['local_pop'].sum())
region_seoul_top_young.reset_index(drop=False, inplace=True)

# 서울 지역 전체 인구수

region_seoul_top_all = pd.DataFrame(region_seoul_top_mean.groupby(['시군구명', '읍면동명'])['local_pop'].sum())
region_seoul_top_all.reset_index(drop=False, inplace=True)



#경기 지역 청장년층 인구수

region_gk_top_young = region_gk_top_mean[(region_gk_top_mean['연령']=='20~24세')
                                        | (region_gk_top_mean['연령']=='25~29세')
                                        | (region_gk_top_mean['연령']=='30~34세')
                                        | (region_gk_top_mean['연령']=='35~39세')]
region_gk_top_young = pd.DataFrame(region_gk_top_young.groupby('시군구명')['전체'].sum())
region_gk_top_young.reset_index(drop=False, inplace=True)

#경기 지역 전체 인구수
region_gk_top_all = pd.DataFrame(region_gk_top_mean.groupby('시군구명')['전체'].sum())
region_gk_top_all.reset_index(drop=False, inplace=True)

# %%
# 청장년층 인구 비율 추가(읍면동별)

region_seoul_top_young['local_all'] = region_seoul_top_all['local_pop']
region_gk_top_young['인구전체'] = region_gk_top_all['전체']

region_seoul_top_young['ratio'] = region_seoul_top_young['local_pop'] / region_seoul_top_young['local_all']
region_gk_top_young['ratio'] = region_gk_top_young['전체']/region_gk_top_young['인구전체']

# %%
# 청장년층 인구 비율(구별)

region_seoul_ratio_all = region_seoul_top_young.groupby('시군구명')['local_pop'].sum()
region_seoul_ratio_all_1 = region_seoul_top_young.groupby('시군구명')['local_all'].sum()

region_seoul_ratio = pd.DataFrame(region_seoul_ratio_all / region_seoul_ratio_all_1)
region_seoul_ratio.columns = ['ratio']
region_seoul_ratio.reset_index(drop=False, inplace=True)

# %% [markdown]
# #### 배달 금액

# %%
# 1차유행 이전/이후 평균 배달 금액 (배달완료, 금액 !=0 데이터 기준)

del_seoul_money_bef = pd.DataFrame(del_seoul_top_bef[(del_seoul_top_bef['배달상태']==1) & 
                                                     (del_seoul_top_bef['상품금액']!=0)].groupby('목적지_시군구명')['상품금액'].mean())
del_seoul_money_af = pd.DataFrame(del_seoul_top_af[(del_seoul_top_af['배달상태']==1) & 
                                                     (del_seoul_top_af['상품금액']!=0)].groupby('목적지_시군구명')['상품금액'].mean())

del_gk_money_bef = pd.DataFrame(del_gk_top_bef[(del_gk_top_bef['배달상태']==1) &
                                              (del_gk_top_bef['상품금액']!=0)].groupby('목적지_시군구명')['상품금액'].mean())
del_gk_money_af = pd.DataFrame(del_gk_top_af[(del_gk_top_af['배달상태']==1) &
                                              (del_gk_top_af['상품금액']!=0)].groupby('목적지_시군구명')['상품금액'].mean())

del_seoul_money_bef.reset_index(drop=False, inplace=True)
del_seoul_money_af.reset_index(drop=False, inplace=True)
del_gk_money_bef.reset_index(drop=False, inplace=True)
del_gk_money_af.reset_index(drop=False, inplace=True)

# %%
# 1차 유행 이전/이후 읍면동별 평균 배달 금액

del_seoul_money_bef_1 = pd.DataFrame(del_seoul_top_bef[(del_seoul_top_bef['배달상태']==1) & 
                                                     (del_seoul_top_bef['상품금액']!=0)].groupby(['목적지_시군구명', '목적지_읍면동명'])['상품금액'].mean())
del_seoul_money_af_1 = pd.DataFrame(del_seoul_top_af[(del_seoul_top_af['배달상태']==1) & 
                                                     (del_seoul_top_af['상품금액']!=0)].groupby(['목적지_시군구명', '목적지_읍면동명'])['상품금액'].mean())

del_gk_money_bef_1 = pd.DataFrame(del_gk_top_bef[(del_gk_top_bef['배달상태']==1) &
                                              (del_gk_top_bef['상품금액']!=0)].groupby(['목적지_시군구명', '목적지_읍면동명'])['상품금액'].mean())
del_gk_money_af_1 = pd.DataFrame(del_gk_top_af[(del_gk_top_af['배달상태']==1) &
                                              (del_gk_top_af['상품금액']!=0)].groupby(['목적지_시군구명', '목적지_읍면동명'])['상품금액'].mean())

del_seoul_money_bef_1.reset_index(drop=False, inplace=True)
del_seoul_money_af_1.reset_index(drop=False, inplace=True)
del_gk_money_bef_1.reset_index(drop=False, inplace=True)
del_gk_money_af_1.reset_index(drop=False, inplace=True)

# %% [markdown]
# #### 배달 시간

# %%
# 배달 완료 상태 데이터만 활용

del_seoul_top_com = del_seoul_top[del_seoul_top['배달상태']==1]
del_gk_top_com = del_gk_top[del_gk_top['배달상태']==1]

del_seoul_top_com['접수시간']= pd.to_datetime(del_seoul_top_com['접수시간'])
del_seoul_top_com['완료시간']= pd.to_datetime(del_seoul_top_com['완료시간'])
del_gk_top_com['접수시간']= pd.to_datetime(del_gk_top_com['접수시간'])
del_gk_top_com['완료시간']= pd.to_datetime(del_gk_top_com['완료시간'])

# 배달시간(분)
del_seoul_top_com['배달시간'] = (del_seoul_top_com['완료시간'] - del_seoul_top_com['접수시간']).astype('timedelta64[m]')
del_gk_top_com['배달시간'] = (del_gk_top_com['완료시간'] - del_gk_top_com['접수시간']).astype('timedelta64[m]')

# %%
# 지역별 평균 배달 시간

del_seoul_top_com_mean = pd.DataFrame(del_seoul_top_com.groupby('목적지_시군구명')['배달시간'].mean())
del_gk_top_com_mean = pd.DataFrame(del_gk_top_com.groupby('목적지_시군구명')['배달시간'].mean())

del_seoul_top_com_mean.reset_index(drop=False, inplace=True)
del_gk_top_com_mean.reset_index(drop=False, inplace=True)

# %%
# 지역, 업종별 평균 배달 시간

del_seoul_top_com_menu = pd.DataFrame(del_seoul_top_com.groupby(['목적지_시군구명', '업종명'])['배달시간'].mean())
del_gk_top_com_menu = pd.DataFrame(del_gk_top_com.groupby(['목적지_시군구명', '업종명'])['배달시간'].mean())

del_seoul_top_com_menu.reset_index(drop=False, inplace=True)
del_gk_top_com_menu.reset_index(drop=False, inplace=True)

# %%
# 1차유행(이전/이후) 평균 배달 시간


del_seoul_top_com_bef = del_seoul_top_bef[del_seoul_top_bef['배달상태']==1]
del_seoul_top_com_af = del_seoul_top_af[del_seoul_top_af['배달상태']==1]
del_gk_top_com_bef = del_gk_top_bef[del_gk_top_bef['배달상태']==1]
del_gk_top_com_af = del_gk_top_af[del_gk_top_af['배달상태']==1]

del_seoul_top_com_bef['접수시간']= pd.to_datetime(del_seoul_top_com_bef['접수시간'])
del_seoul_top_com_bef['완료시간']= pd.to_datetime(del_seoul_top_com_bef['완료시간'])
del_seoul_top_com_af['접수시간']= pd.to_datetime(del_seoul_top_com_af['접수시간'])
del_seoul_top_com_af['완료시간']= pd.to_datetime(del_seoul_top_com_af['완료시간'])
del_gk_top_com_bef['접수시간']= pd.to_datetime(del_gk_top_com_bef['접수시간'])
del_gk_top_com_bef['완료시간']= pd.to_datetime(del_gk_top_com_bef['완료시간'])
del_gk_top_com_af['접수시간']= pd.to_datetime(del_gk_top_com_af['접수시간'])
del_gk_top_com_af['완료시간']= pd.to_datetime(del_gk_top_com_af['완료시간'])

# 배달시간(분)
del_seoul_top_com_bef['배달시간'] = (del_seoul_top_com_bef['완료시간'] - del_seoul_top_com_bef['접수시간']).astype('timedelta64[m]')
del_seoul_top_com_af['배달시간'] = (del_seoul_top_com_af['완료시간'] - del_seoul_top_com_af['접수시간']).astype('timedelta64[m]')
del_gk_top_com_bef['배달시간'] = (del_gk_top_com_bef['완료시간'] - del_gk_top_com_bef['접수시간']).astype('timedelta64[m]')
del_gk_top_com_af['배달시간'] = (del_gk_top_com_af['완료시간'] - del_gk_top_com_af['접수시간']).astype('timedelta64[m]')

# %%
# 1차유행(이전/이후) 지역별 평균 배달 시간

del_seoul_top_com_mean_bef = pd.DataFrame(del_seoul_top_com_bef.groupby('목적지_시군구명')['배달시간'].mean())
del_seoul_top_com_mean_af = pd.DataFrame(del_seoul_top_com_af.groupby('목적지_시군구명')['배달시간'].mean())
del_gk_top_com_mean_bef = pd.DataFrame(del_gk_top_com_bef.groupby('목적지_시군구명')['배달시간'].mean())
del_gk_top_com_mean_af = pd.DataFrame(del_gk_top_com_af.groupby('목적지_시군구명')['배달시간'].mean())

del_seoul_top_com_mean_bef.reset_index(drop=False, inplace=True)
del_seoul_top_com_mean_af.reset_index(drop=False, inplace=True)
del_gk_top_com_mean_bef.reset_index(drop=False, inplace=True)
del_gk_top_com_mean_af.reset_index(drop=False, inplace=True)

# %% [markdown]
# - 코로나 확진자수(지역별)

# %%
corona = pd.read_csv('TimeProvince.csv')

corona['date'] = pd.to_datetime(corona['date'])
corona = corona[corona['date'] <= '2020-06-01'] # 20.05.31 이전 확진자수
corona = corona.drop(['time', 'released', 'deceased'], axis=1)

corona_seoul = corona[corona['province']=='Seoul']
corona_gk = corona[corona['province']=='Gyeonggi-do']
corona_dg = corona[corona['province']=='Daegu']

corona_seoul.reset_index(drop=True, inplace=True)
corona_gk.reset_index(drop=True, inplace=True)
corona_dg.reset_index(drop=True, inplace=True)

# %%
# 일일 확진자수

for i in corona_seoul.index:
    if i == 0:
        corona_seoul.loc[0, 'day_confirmed'] = 0
        corona_gk.loc[0, 'day_confirmed'] = 0
        corona_dg.loc[0, 'day_confirmed'] = 0
    else:
        corona_seoul.loc[i, 'day_confirmed'] = corona_seoul.loc[i, 'confirmed'] - corona_seoul.loc[i-1, 'confirmed']
        corona_gk.loc[i, 'day_confirmed'] = corona_gk.loc[i, 'confirmed'] - corona_gk.loc[i-1, 'confirmed']
        corona_dg.loc[i, 'day_confirmed'] = corona_dg.loc[i, 'confirmed'] - corona_dg.loc[i-1, 'confirmed']

# %% [markdown]
# #### 육체건강

# %%
bodyhealth = pd.read_csv('./DATA/bodyhealth.csv')

# %% [markdown]
# # **성현님**

# %%
df_deliver = pd.read_csv("./dlvr_call.csv", low_memory=False)

# %%
df_deliver.head()
# Out:
#         SN  PROCESS_DT DLVR_REQUST_ENTRPS_ID  DLVR_REQUST_STTUS_VALUE  \
# 0  3486929  2019-12-01               C000101                        1
# 1  3486930  2019-12-01               C000099                        1
# 2  3486932  2019-12-01               C000029                        1
# 3  3486933  2019-12-01               C000105                        1
# 4  3486934  2019-12-01               C000028                        1
#
#   DLVR_RCEPT_ENTRPS_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# 0              C000101      S0021950                족발/보쌈
# 1              C000099      S0039210                   치킨
# 2              C000043      S0036135                   치킨
# 3              C000105      S0039956               돈까스/일식
# 4              C000043      S0003074                   치킨
#
#    DLVR_STORE_LEGALDONG_CODE DLVR_STORE_BRTC_NM DLVR_STORE_SIGNGU_NM  \
# 0                 1156013200              서울특별시                 영등포구
# ...

# %%
df_deliver.isnull().sum()
# Out:
# SN                                 0
# PROCESS_DT                         0
# DLVR_REQUST_ENTRPS_ID              0
# DLVR_REQUST_STTUS_VALUE            0
# DLVR_RCEPT_ENTRPS_ID               0
# DLVR_STORE_ID                      0
# DLVR_STORE_INDUTY_NM               0
# DLVR_STORE_LEGALDONG_CODE          0
# DLVR_STORE_BRTC_NM                 0
# DLVR_STORE_SIGNGU_NM               0
# DLVR_STORE_LEGALDONG_NM            0
# DLVR_STORE_LI_NM                   0
# DLVR_STORE_ADSTRD_CODE             0
# DLVR_STORE_RDNMADR_CODE            0
# DLVR_DSTN_LEGALDONG_CODE           0
# DLVR_DSTN_BRTC_NM                  0
# DLVR_DSTN_SIGNGU_NM                0
# DLVR_DSTN_LEGALDONG_NM             0
# DLVR_DSTN_LI_NM                    0
# DLVR_DSTN_ADSTRD_CODE              0
# DLVR_DSTN_RDNMADR_CODE             0
# DLVR_MAN_ID                        0
# DLVR_AMOUNT                        0
# CALL_RLAY_FEE_AMOUNT               0
# GOODS_AMOUNT                       0
# ...

# %%
df_deliver['DLVR_STORE_BRTC_NM'].unique()
# Out:
# array(['서울특별시', '경기도'], dtype=object)

# %%
df_deliver['DLVR_DSTN_BRTC_NM'].unique()
# Out:
# array(['서울특별시', '경기도', '인천광역시', '경상남도', '충청남도', '전라북도', '부산광역시', '경상북도',
#        '울산광역시', '대전광역시', '대구광역시', '전라남도', '세종특별자치시', '강원도', '충청북도',
#        '제주특별자치도', '광주광역시'], dtype=object)

# %%
### 경기도 → 제주도 배달 시간 20분? 이상함
df_deliver[df_deliver['DLVR_DSTN_BRTC_NM'] == '제주특별자치도']
# Out:
#               SN  PROCESS_DT DLVR_REQUST_ENTRPS_ID  DLVR_REQUST_STTUS_VALUE  \
# 1873698  6462121  2020-02-26               C000312                        1
#
#         DLVR_RCEPT_ENTRPS_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# 1873698              C000312      S0027026                   중식
#
#          DLVR_STORE_LEGALDONG_CODE DLVR_STORE_BRTC_NM DLVR_STORE_SIGNGU_NM  \
# 1873698                 4125010300                경기도                 동두천시
#
#         DLVR_STORE_LEGALDONG_NM DLVR_STORE_LI_NM  DLVR_STORE_ADSTRD_CODE  \
# 1873698                     생연동               \N              4125053500
#
#         DLVR_STORE_RDNMADR_CODE  DLVR_DSTN_LEGALDONG_CODE DLVR_DSTN_BRTC_NM  \
# 1873698            412504367135                5011010300           제주특별자치도
#
#         DLVR_DSTN_SIGNGU_NM DLVR_DSTN_LEGALDONG_NM DLVR_DSTN_LI_NM  \
# 1873698                 제주시                   이도일동              \N
#
#         DLVR_DSTN_ADSTRD_CODE DLVR_DSTN_RDNMADR_CODE DLVR_MAN_ID  DLVR_AMOUNT  \
# ...

# %%
### 서울, 경기도만 사용
df_deliver = df_deliver[(df_deliver['DLVR_DSTN_BRTC_NM'] == '서울특별시') | (df_deliver['DLVR_DSTN_BRTC_NM'] == '경기도')]

# %%
### 배달 완료만 사용
df_deliver = df_deliver[df_deliver['DLVR_REQUST_STTUS_VALUE'] == 1]

# %%
df_deliver['DLVR_STORE_INDUTY_NM'].unique()
# Out:
# array(['족발/보쌈', '치킨', '돈까스/일식', '아시안/양식', '카페/디저트', '패스트푸드', '분식', '회',
#        '야식', '한식', '배달전문업체', '중식', '피자', '찜탕', '도시락', '심부름'], dtype=object)

# %%
df_deliver['PROCESS_DT'] = pd.to_datetime(df_deliver['PROCESS_DT'])

# %%
df_deliver_s = df_deliver[df_deliver['DLVR_DSTN_BRTC_NM'] == '서울특별시']
df_deliver_g = df_deliver[df_deliver['DLVR_DSTN_BRTC_NM'] == '경기도']

# %% [markdown]
# **코로나 전후 업종별 배달 건수 변화**

# %%
df_deliver_s_bc_store = pd.DataFrame(df_deliver_s[df_deliver_s['PROCESS_DT'] < '2020-02-29'].groupby('DLVR_STORE_INDUTY_NM').size())
df_deliver_s_ac_store = pd.DataFrame(df_deliver_s[df_deliver_s['PROCESS_DT'] >= '2020-02-29'].groupby('DLVR_STORE_INDUTY_NM').size())
df_deliver_g_bc_store = pd.DataFrame(df_deliver_g[df_deliver_g['PROCESS_DT'] < '2020-02-29'].groupby('DLVR_STORE_INDUTY_NM').size())
df_deliver_g_ac_store = pd.DataFrame(df_deliver_g[df_deliver_g['PROCESS_DT'] >= '2020-02-29'].groupby('DLVR_STORE_INDUTY_NM').size())

# %%
df_deliver_s_bc_store['지역'] = '서울특별시'
df_deliver_s_bc_store['기간'] = '코로나 이전'
df_deliver_s_bc_store.reset_index(inplace=True)
df_deliver_s_bc_store.rename(columns={0: '배달건수'}, inplace=True)

df_deliver_s_ac_store['지역'] = '서울특별시'
df_deliver_s_ac_store['기간'] = '코로나 이후'
df_deliver_s_ac_store.reset_index(inplace=True)
df_deliver_s_ac_store.rename(columns={0: '배달건수'}, inplace=True)

df_deliver_g_bc_store['지역'] = '경기도'
df_deliver_g_bc_store['기간'] = '코로나 이전'
df_deliver_g_bc_store.reset_index(inplace=True)
df_deliver_g_bc_store.rename(columns={0: '배달건수'}, inplace=True)

df_deliver_g_ac_store['지역'] = '경기도'
df_deliver_g_ac_store['기간'] = '코로나 이후'
df_deliver_g_ac_store.reset_index(inplace=True)
df_deliver_g_ac_store.rename(columns={0: '배달건수'}, inplace=True)

# %%
df_deliver_s_store = pd.concat([df_deliver_s_bc_store, df_deliver_s_ac_store])
df_deliver_g_store = pd.concat([df_deliver_g_bc_store, df_deliver_g_ac_store])

# %% [markdown]
# **코로나 전후 지역별 배달 건수 변화**

# %%
df_deliver_s_bc_n = pd.DataFrame(df_deliver_s[df_deliver_s['PROCESS_DT'] < '2020-02-29'].groupby('DLVR_DSTN_SIGNGU_NM').size())
df_deliver_s_ac_n = pd.DataFrame(df_deliver_s[df_deliver_s['PROCESS_DT'] >= '2020-02-29'].groupby('DLVR_DSTN_SIGNGU_NM').size())
df_deliver_g_bc_n = pd.DataFrame(df_deliver_g[df_deliver_g['PROCESS_DT'] < '2020-02-29'].groupby('DLVR_DSTN_SIGNGU_NM').size())
df_deliver_g_ac_n = pd.DataFrame(df_deliver_g[df_deliver_g['PROCESS_DT'] >= '2020-02-29'].groupby('DLVR_DSTN_SIGNGU_NM').size())

# %%
df_deliver_s_bc_n.rename(columns={0: '코로나 이전'}, inplace=True)
df_deliver_s_ac_n.rename(columns={0: '코로나 이후'}, inplace=True)
df_deliver_g_bc_n.rename(columns={0: '코로나 이전'}, inplace=True)
df_deliver_g_ac_n.rename(columns={0: '코로나 이후'}, inplace=True)

# %%
df_deliver_s_n = pd.merge(df_deliver_s_bc_n, df_deliver_s_ac_n, left_index=True, right_index=True, how='outer')
df_deliver_g_n = pd.merge(df_deliver_g_bc_n, df_deliver_g_ac_n, left_index=True, right_index=True, how='outer')

# %%
df_deliver_s_n['증가율'] = round((df_deliver_s_n['코로나 이후'] - df_deliver_s_n['코로나 이전']) / df_deliver_s_n['코로나 이전'] * 100, 1)
df_deliver_g_n['증가율'] = round((df_deliver_g_n['코로나 이후'] - df_deliver_g_n['코로나 이전']) / df_deliver_g_n['코로나 이전'] * 100, 1)

# %%
### 1건에서 2건이 되면 100% 증가 / 주문 건수 0건 등이 있어서 전체 주문건수 상위 25%에 대해 증가율 계산
s_q3 = np.percentile(df_deliver_s.groupby('DLVR_DSTN_SIGNGU_NM').size(), 75)
g_q3 = np.percentile(df_deliver_g.groupby('DLVR_DSTN_SIGNGU_NM').size(), 75)

# %%
df_deliver_s_n = df_deliver_s_n.loc[df_deliver_s.groupby('DLVR_DSTN_SIGNGU_NM').size()
                                    [df_deliver_s.groupby('DLVR_DSTN_SIGNGU_NM').size() > s_q3].index]
df_deliver_g_n = df_deliver_g_n.loc[df_deliver_g.groupby('DLVR_DSTN_SIGNGU_NM').size()
                                    [df_deliver_g.groupby('DLVR_DSTN_SIGNGU_NM').size() > g_q3].index]

# %% [markdown]
# **코로나 전후 주문 시간 변화**

# %%
df_deliver['DLVR_RCEPT_TIME'] = pd.to_datetime(df_deliver['DLVR_RCEPT_TIME'])

# %%
df_deliver['배달 접수 시간'] = df_deliver['DLVR_RCEPT_TIME'].apply(lambda x: x.hour)

# %%
df_deliver['배달 접수 요일'] = df_deliver['DLVR_RCEPT_TIME'].dt.weekday

# %%
df_deliver['배달 접수 평일/주말'] = df_deliver['배달 접수 요일'].apply(lambda x: '주말' if (x == 5)|(x == 6)
                                                                                         else '평일')

# %%
df_deliver_s = df_deliver[df_deliver['DLVR_DSTN_BRTC_NM'] == '서울특별시']
df_deliver_g = df_deliver[df_deliver['DLVR_DSTN_BRTC_NM'] == '경기도']

# %%
df_deliver_s_bc_time = pd.DataFrame(df_deliver_s[df_deliver_s['PROCESS_DT'] < '2020-02-29'].groupby('배달 접수 시간').size())
df_deliver_s_ac_time = pd.DataFrame(df_deliver_s[df_deliver_s['PROCESS_DT'] >= '2020-02-29'].groupby('배달 접수 시간').size())
df_deliver_g_bc_time = pd.DataFrame(df_deliver_g[df_deliver_g['PROCESS_DT'] < '2020-02-29'].groupby('배달 접수 시간').size())
df_deliver_g_ac_time = pd.DataFrame(df_deliver_g[df_deliver_g['PROCESS_DT'] >= '2020-02-29'].groupby('배달 접수 시간').size())

# %%
df_deliver_s_bc_time['지역'] = '서울특별시'
df_deliver_s_bc_time['기간'] = '코로나 이전'
df_deliver_s_bc_time.reset_index(inplace=True)
df_deliver_s_bc_time.rename(columns={0: '배달건수'}, inplace=True)

df_deliver_s_ac_time['지역'] = '서울특별시'
df_deliver_s_ac_time['기간'] = '코로나 이후'
df_deliver_s_ac_time.reset_index(inplace=True)
df_deliver_s_ac_time.rename(columns={0: '배달건수'}, inplace=True)

df_deliver_g_bc_time['지역'] = '경기도'
df_deliver_g_bc_time['기간'] = '코로나 이전'
df_deliver_g_bc_time.reset_index(inplace=True)
df_deliver_g_bc_time.rename(columns={0: '배달건수'}, inplace=True)

df_deliver_g_ac_time['지역'] = '경기도'
df_deliver_g_ac_time['기간'] = '코로나 이후'
df_deliver_g_ac_time.reset_index(inplace=True)
df_deliver_g_ac_time.rename(columns={0: '배달건수'}, inplace=True)

# %%
df_deliver_s_time = pd.concat([df_deliver_s_bc_time, df_deliver_s_ac_time])
df_deliver_g_time = pd.concat([df_deliver_g_bc_time, df_deliver_g_ac_time])

# %% [markdown]
# **코로나 전후 주문 요일 변화**

# %%
df_deliver_s_bc_week = pd.DataFrame(df_deliver_s[df_deliver_s['PROCESS_DT'] < '2020-02-29'].groupby('배달 접수 요일').size())
df_deliver_s_ac_week = pd.DataFrame(df_deliver_s[df_deliver_s['PROCESS_DT'] >= '2020-02-29'].groupby('배달 접수 요일').size())
df_deliver_g_bc_week = pd.DataFrame(df_deliver_g[df_deliver_g['PROCESS_DT'] < '2020-02-29'].groupby('배달 접수 요일').size())
df_deliver_g_ac_week = pd.DataFrame(df_deliver_g[df_deliver_g['PROCESS_DT'] >= '2020-02-29'].groupby('배달 접수 요일').size())

# %%
df_deliver_s_bc_week['지역'] = '서울특별시'
df_deliver_s_bc_week['기간'] = '코로나 이전'
df_deliver_s_bc_week.reset_index(inplace=True)
df_deliver_s_bc_week.rename(columns={0: '배달건수'}, inplace=True)

df_deliver_s_ac_week['지역'] = '서울특별시'
df_deliver_s_ac_week['기간'] = '코로나 이후'
df_deliver_s_ac_week.reset_index(inplace=True)
df_deliver_s_ac_week.rename(columns={0: '배달건수'}, inplace=True)

df_deliver_g_bc_week['지역'] = '경기도'
df_deliver_g_bc_week['기간'] = '코로나 이전'
df_deliver_g_bc_week.reset_index(inplace=True)
df_deliver_g_bc_week.rename(columns={0: '배달건수'}, inplace=True)

df_deliver_g_ac_week['지역'] = '경기도'
df_deliver_g_ac_week['기간'] = '코로나 이후'
df_deliver_g_ac_week.reset_index(inplace=True)
df_deliver_g_ac_week.rename(columns={0: '배달건수'}, inplace=True)

# %%
df_deliver_s_week = pd.concat([df_deliver_s_bc_week, df_deliver_s_ac_week])
df_deliver_g_week = pd.concat([df_deliver_g_bc_week, df_deliver_g_ac_week])

# %%
display(df_deliver_s_week[:7])
display(df_deliver_s_week[7:])
# Out:
#    배달 접수 요일   배달건수     지역      기간
# 0         0  60695  서울특별시  코로나 이전
# 1         1  66314  서울특별시  코로나 이전
# 2         2  62667  서울특별시  코로나 이전
# 3         3  59873  서울특별시  코로나 이전
# 4         4  70802  서울특별시  코로나 이전
# 5         5  76453  서울특별시  코로나 이전
# 6         6  81071  서울특별시  코로나 이전
#    배달 접수 요일    배달건수     지역      기간
# 0         0   54999  서울특별시  코로나 이후
# 1         1   63898  서울특별시  코로나 이후
# 2         2   63302  서울특별시  코로나 이후
# 3         3   64434  서울특별시  코로나 이후
# 4         4   77923  서울특별시  코로나 이후
# 5         5   95017  서울특별시  코로나 이후
# 6         6  103832  서울특별시  코로나 이후

# %%
display(df_deliver_g_week[:7])
display(df_deliver_g_week[7:])
# Out:
#    배달 접수 요일    배달건수   지역      기간
# 0         0  186628  경기도  코로나 이전
# 1         1  201025  경기도  코로나 이전
# 2         2  192284  경기도  코로나 이전
# 3         3  182714  경기도  코로나 이전
# 4         4  207915  경기도  코로나 이전
# 5         5  215851  경기도  코로나 이전
# 6         6  232162  경기도  코로나 이전
#    배달 접수 요일    배달건수   지역      기간
# 0         0  190890  경기도  코로나 이후
# 1         1  228278  경기도  코로나 이후
# 2         2  224631  경기도  코로나 이후
# 3         3  225395  경기도  코로나 이후
# 4         4  265383  경기도  코로나 이후
# 5         5  315527  경기도  코로나 이후
# 6         6  343501  경기도  코로나 이후

# %% [markdown]
# - 건강(육체)

# %%
# 연도별 육체건강 관련 지표

bodyhealth = pd.read_csv('./DATA/bodyhealth.csv')

# %% [markdown]
# ## **행정안전부 업종별 개폐업 데이터**
#
# * 행정안전부에서는 지방자치단체에 축적되는 인허가
# 데이터를 수집하여 개방하고 있습니다. 코로나 전후의 요식업 변화를 명확하게 비교하기 위하여 일반음식점과 휴게음식점의 개폐업 인허가 데이터를 사용하였습니다.현제 다운로드 가능한 데이터의 수집기간은 2021년 7월 31일까지 입니다
# * 일반음식점 : 	한식, 중식, 일식 등 음식류를 조리 및 판매하며, 식사와 함께 음주행위가 허용되는 업소정보
# * 휴게음식점 : 주로 다류, 아이스크림류 등을 조리하여 판매하거나 패스트푸드점 또는 공항 등에서 음식류를 조리하여 판매하며, 음주행위가 허용되지 않는 업소정보
# * 출처 : https://www.localdata.go.kr/devcenter/dataDown.do?menuNo=20001

# %%
korea=pd.read_csv("./fulldata_07_24_04_P_일반음식점.csv",encoding='cp949')
korea2 = pd.read_csv(".//fulldata_07_24_05_P_휴게음식점.csv",encoding='cp949')

# %%
korea.shape
# Out:
# (1950134, 48)

# %%
print ('일반 음식점 개폐업 인허가 데이터 shape :' , korea.shape)
print ('휴게 음식점 개폐업 인허가 데이터 shape :' , korea2.shape)
# Out:
# 일반 음식점 개폐업 인허가 데이터 shape : (1950134, 48)
# 휴게 음식점 개폐업 인허가 데이터 shape : (470195, 48)

# %%
display(korea.head(3))
display(korea2.tail(3))
# Out:
#    번호 개방서비스명     개방서비스id  개방자치단체코드                    관리번호     인허가일자  인허가취소일자  \
# 0   1  일반음식점  07_24_04_P   3600000  3600000-101-2014-00100  20140508      NaN
# 1   2  일반음식점  07_24_04_P   3600000  3600000-101-2014-00059  20140319      NaN
# 2   3  일반음식점  07_24_04_P   3600000  3600000-101-2014-00060  20140321      NaN
#
#    영업상태구분코드  영업상태명  상세영업상태코드 상세영업상태명 폐업일자  휴업시작일자  휴업종료일자  재개업일자 소재지전화  소재지면적  \
# 0         1  영업/정상         1      영업  NaN     NaN     NaN    NaN   NaN  99.00
# 1         1  영업/정상         1      영업  NaN     NaN     NaN    NaN   NaN  82.60
# 2         1  영업/정상         1      영업  NaN     NaN     NaN    NaN   NaN  26.40
#
#     소재지우편번호                    소재지전체주소                           도로명전체주소  \
# 0  502831.0  광주광역시 서구 풍암동 682-1번지 (1층)      광주광역시 서구 송풍로17번길 5, 1층 (풍암동)
# 1  502834.0    광주광역시 서구 화정동 70-61 (1층)    광주광역시 서구 내방로350번길 10, 1층 (화정동)
# 2  502837.0  광주광역시 서구 화정동 332-9번지 (1층)  광주광역시 서구 월드컵4강로116번길 5, 1층 (화정동)
#
# ...

# %%
korea.isnull().sum()
# Out:
# 번호                   0
# 개방서비스명               0
# 개방서비스id              0
# 개방자치단체코드             0
# 관리번호                 0
# 인허가일자                0
# 인허가취소일자        1950134
# 영업상태구분코드             0
# 영업상태명                0
# 상세영업상태코드             0
# 상세영업상태명              0
# 폐업일자            679821
# 휴업시작일자         1950134
# 휴업종료일자         1950134
# 재개업일자          1950134
# 소재지전화           576874
# 소재지면적           139799
# 소재지우편번호          63968
# 소재지전체주소           4163
# 도로명전체주소         828100
# 도로명우편번호         847235
# 사업장명                 1
# 최종수정시점               0
# 데이터갱신구분              0
# 데이터갱신일자              0
# 업태구분명              173
# 좌표정보(x)         102678
# 좌표정보(y)         102678
# 위생업태명            19697
# 남성종사자수          925338
# 여성종사자수          910016
# 영업장주변구분명       1130637
# 등급구분명          1505319
# 급수시설구분명         656405
# 총종업원수          1932334
# 본사종업원수         1901338
# 공장사무직종업원수      1901342
# 공장판매직종업원수      1901342
# 공장생산직종업원수      1901342
# 건물소유구분명        1950127
# ...

# %%
korea2.isnull().sum()
# Out:
# 번호                  0
# 개방서비스명              0
# 개방서비스id             0
# 개방자치단체코드            0
# 관리번호                0
# 인허가일자               0
# 인허가취소일자        470195
# 영업상태구분코드            0
# 영업상태명               0
# 상세영업상태코드            0
# 상세영업상태명             0
# 폐업일자           185858
# 휴업시작일자         470195
# 휴업종료일자         470195
# 재개업일자          470195
# 소재지전화          228225
# 소재지면적           35623
# 소재지우편번호         16125
# 소재지전체주소          1880
# 도로명전체주소        139611
# 도로명우편번호        144290
# 사업장명                0
# 최종수정시점              0
# 데이터갱신구분             0
# 데이터갱신일자             0
# 업태구분명              16
# 좌표정보(x)         20864
# 좌표정보(y)         20864
# 위생업태명            4273
# 남성종사자수         335187
# 여성종사자수         329908
# 영업장주변구분명       334231
# 등급구분명          401895
# 급수시설구분명        190291
# 총종업원수          464217
# 본사종업원수         459590
# 공장사무직종업원수      459590
# 공장판매직종업원수      459590
# 공장생산직종업원수      459590
# 건물소유구분명        470179
# 보증액            459596
# ...

# %%
# 휴게음식점 데이터와 일반음식점 데이터는 형태가 동일하므로 둘을 병합해줍니다
official = pd.concat([korea,korea2])

# 불필요한 데이터 제거
official = official.drop(['번호','개방서비스명','개방서비스id','개방자치단체코드','관리번호','휴업시작일자','휴업종료일자','재개업일자','소재지전화','소재지면적','소재지우편번호','도로명우편번호','최종수정시점','데이터갱신구분','데이터갱신일자','좌표정보(x)','좌표정보(y)',
                       '영업장주변구분명','등급구분명','급수시설구분명','총종업원수','본사종업원수','공장사무직종업원수','공장판매직종업원수','공장생산직종업원수','건물소유구분명','보증액','월세액','전통업소지정번호','홈페이지','Unnamed: 47','전통업소주된음식','시설총규모',
                       '인허가취소일자','남성종사자수','여성종사자수','다중이용업소여부','위생업태명'],axis=1)


# 배달 데이터와의 통일성 위해 서울과 경기 데이터만 사용
off_seoul=official[official['소재지전체주소'].str.contains('서울특별시',na=False)]
off_gyeong=official[official['소재지전체주소'].str.contains('경기도',na=False)]

# 샐러드 가게는 사업장명으로 구분해야 하기 때문에 사업장명이 NaN인 행은 제거
off_seoul.dropna(subset=['사업장명'],axis=0,inplace=True)
off_gyeong.dropna(subset=['사업장명'],axis=0,inplace=True)

off_seoul.reset_index(drop=True, inplace = True)
off_gyeong.reset_index(drop=True, inplace = True)

off_seoul = off_seoul.drop(202207)
off_seoul.폐업일자 = pd.to_numeric(off_seoul.폐업일자)
off_gyeong.폐업일자 = pd.to_numeric(off_gyeong.폐업일자)

# %% [markdown]
# official 데이터의 수집기간은 21년 7월 31일까지입니다.따라서 **코로나 확진자 수가 처음으로 급증한 2020년 2월 29일을 기준**으로
# * 코로나 이후 : 20년 2월 29일부터 21년 7월 31일까지
# * 코로나 이전 : 코로나 이후와 동기간인 18년 9월 27일부터 20년 2월 28일까지
#
# 로 나누어 분석하였습니다.

# %%
seoul_p = off_seoul[(off_seoul['폐업일자']>=20180927) | (off_seoul['폐업일자']>=20180927) ]
gyeong_p = off_gyeong[(off_gyeong['폐업일자']>=20180927) | (off_gyeong['폐업일자']>=20180927) ]
display(seoul_p[(seoul_p['사업장명'].str.contains('야채'))])
display(gyeong_p[(gyeong_p['사업장명'].str.contains('채소'))])

# %%
display(seoul_p[(seoul_p['사업장명'].str.contains('채소'))][['인허가일자','영업상태명','폐업일자','소재지전체주소','사업장명']].head(3))
display(gyeong_p[(gyeong_p['사업장명'].str.contains('야채'))][['인허가일자','영업상태명','폐업일자','소재지전체주소','사업장명']].head(3))
# Out:
#            인허가일자 영업상태명        폐업일자                      소재지전체주소 사업장명
# 293755  20060510    폐업  20190617.0  서울특별시 강북구 번동 123-1번지 (지상1층)  채소야
# 302669  20030214    폐업  20210316.0   서울특별시 구로구 구로동 771-27 ,101호  채소야
#            인허가일자 영업상태명        폐업일자                  소재지전체주소          사업장명
# 185367  20150826    폐업  20200122.0  경기도 평택시 서정동 335-13번지 B동       동대문야채곱창
# 190806  20010531    폐업  20210331.0     경기도 양주시 남면 신산리 290-3       신산리야채곱창
# 210219  19970319    폐업  20210524.0  경기도 의정부시 호원동 454-6 지상1층  신가네춘천닭갈비야채곱창

# %%
salad_seoul = off_seoul[off_seoul['사업장명'].str.contains('샐러' )]
salad_seoul = salad_seoul[~(salad_seoul.사업장명.str.contains('샤브'))]
salad_seoul = salad_seoul[~(salad_seoul.사업장명.str.contains('샐러드바'))]

salad_gyeong = off_gyeong[off_gyeong['사업장명'].str.contains('샐러' )]
mask = (off_gyeong['사업장명'].str.contains('샐러드바')) | off_gyeong['사업장명'].str.contains('샤브')
salad_gyeong= salad_gyeong[~mask]

# %%
salad_seoul_closed = salad_seoul[salad_seoul['영업상태명'] == '폐업']
salad_seoul_closed_af = salad_seoul_closed[salad_seoul_closed['폐업일자']>=20200229]
salad_seoul_closed_bf = salad_seoul_closed[salad_seoul_closed['폐업일자']>=20180927] 
salad_seoul_closed_bf = salad_seoul_closed_bf[salad_seoul_closed_bf['폐업일자']<=20200228]

salad_seoul_open = salad_seoul[salad_seoul['영업상태명'] == '영업/정상']
salad_seoul_open_af = salad_seoul_open[salad_seoul_open['인허가일자']>=20200229]
salad_seoul_open_bf = salad_seoul_open[salad_seoul_open['인허가일자']>=20180927] 
salad_seoul_open_bf = salad_seoul_open_bf[salad_seoul_open_bf['인허가일자']<=20200228]

salad_gyeong_closed = salad_gyeong[salad_gyeong['영업상태명'] == '폐업']
salad_gyeong_closed_af = salad_gyeong_closed[salad_gyeong_closed['폐업일자']>=20200229]
salad_gyeong_closed_bf = salad_gyeong_closed[salad_gyeong_closed['폐업일자']>=20180927] 
salad_gyeong_closed_bf = salad_gyeong_closed_bf[salad_gyeong_closed_bf['폐업일자']<=20200228]

salad_gyeong_open = salad_gyeong[salad_gyeong['영업상태명'] == '영업/정상']
salad_gyeong_open_af = salad_gyeong_open[salad_gyeong_open['인허가일자']>=20200229]
salad_gyeong_open_bf = salad_gyeong_open[salad_gyeong_open['인허가일자']>=20180927] 
salad_gyeong_open_bf = salad_gyeong_open_bf[salad_gyeong_open_bf['인허가일자']<=20200228]

# %%
display(salad_seoul_closed_bf.head())
# Out:
#            인허가일자  영업상태구분코드 영업상태명  상세영업상태코드 상세영업상태명        폐업일자  \
# 163107  20190415         3    폐업         2      폐업  20191216.0
# 237807  20190708         3    폐업         2      폐업  20191203.0
# 246551  20170615         3    폐업         2      폐업  20180928.0
# 269443  20160419         3    폐업         2      폐업  20191121.0
# 295921  20171107         3    폐업         2      폐업  20200225.0
#
#                                           소재지전체주소  \
# 163107  서울특별시 서초구 서초동 1678-2번지 서초동동아빌라트 지하1층 B21호
# 237807       서울특별시 서초구 서초동 1678-2번지 서초동동아빌라트 지하1층
# 246551                         서울특별시 용산구 한남동 93번지
# 269443                        서울특별시 송파구 문정동 644번지
# 295921            서울특별시 강서구 마곡동 774-5번지 랑데르2 103호
#
#                                                   도로명전체주소  \
# 163107      서울특별시 서초구 서초대로 350, 지하1층 B21호 (서초동, 서초동동아빌라트)
# 237807     서울특별시 서초구 서초대로 350, 지하1층 주방21호 (서초동, 서초동동아빌라트)
# 246551                 서울특별시 용산구 독서당로 46, 2층 212-2호 (한남동)
# ...

# %% [markdown]
# ### pyecharts

# %% [markdown]
# ### 코로나확진자

# %%
# 지역별 총 코로나 확진자 수

corona_confirmed = (Line(init_opts=opts.InitOpts(theme=ThemeType.SHINE, height='500px', width='800px'))
                   .add_xaxis(corona_seoul['date'].astype(str).tolist())
                   .add_yaxis('서울', corona_seoul['confirmed'].tolist())
                   .add_yaxis('경기', corona_gk['confirmed'].tolist())
                   .add_yaxis('대구', corona_dg['confirmed'].tolist())
                   .set_global_opts(title_opts=opts.TitleOpts(title='지역별 코로나 확진자 수 누적'),
                                   xaxis_opts=opts.AxisOpts(name='날짜'),
                                   yaxis_opts=opts.AxisOpts(name='확진자 수', name_location="end"),
                                   tooltip_opts=opts.TooltipOpts(trigger='axis', axis_pointer_type='cross'),
                                   legend_opts=opts.LegendOpts(pos_top='5%', pos_right='20%', legend_icon='pin'))
)

# %%
# 지역별 일일 코로나 확진자 수

corona_confirmed1 = (Line(init_opts=opts.InitOpts(theme=ThemeType.SHINE, height='500px', width='800px'))
                   .add_xaxis(corona_seoul['date'].astype(str).tolist())
                   .add_yaxis('서울', corona_seoul['day_confirmed'].tolist())
                   .add_yaxis('경기', corona_gk['day_confirmed'].tolist())
                   .add_yaxis('대구', corona_dg['day_confirmed'].tolist())
                   .set_global_opts(title_opts=opts.TitleOpts(title='지역별 일일 코로나 확진자 수'),
                                   xaxis_opts=opts.AxisOpts(name='날짜'),
                                   yaxis_opts=opts.AxisOpts(name='확진자 수', name_location="end"),
                                   tooltip_opts=opts.TooltipOpts(trigger='axis', axis_pointer_type='cross'),
                                   legend_opts=opts.LegendOpts(pos_top='5%', pos_right='20%', legend_icon='pin'))
)

# %% [markdown]
# ### 배달 요청 수

# %%
del_seoul_gk_tab = Tab()

# 1차유행 이전/이후 배달 요청 수(서울)

bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='800px'))
    .add_xaxis(del_seoul_top_bef_count.index.tolist())
    .add_yaxis("1차유행 이전", del_seoul_top_bef_count['목적지_시군구명'].tolist())
    .add_yaxis("1차유행 이후", del_seoul_top_af_count['목적지_시군구명'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 평균 배달 요청 수 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='배달 요청 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

# 1차유행 이전/이후 배달 요청 수(경기)

bar1= (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='800px'))
    .add_xaxis(del_gk_top_bef_count.index.tolist())
    .add_yaxis("1차유행 이전", del_gk_top_bef_count['목적지_시군구명'].tolist())
    .add_yaxis("1차유행 이후", del_gk_top_af_count['목적지_시군구명'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 평균 배달 요청 수 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='배달 요청 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

del_seoul_gk_tab.add(bar, "서울")
del_seoul_gk_tab.add(bar1, "경기")

# %%
del_seoul_gk_tab_1 = Tab()

# 1차유행 이전/이후 배달 요청 수(서울) + 읍면동

bar_count = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='800px'))
    .add_xaxis(del_seoul_top_bef_count2[del_seoul_top_bef_count2['목적지_시군구명']=='구로구']['목적지_읍면동명'].unique().tolist())
    .add_yaxis("1차유행 이전", del_seoul_top_bef_count2[del_seoul_top_bef_count2['목적지_시군구명']=='구로구']['수'].tolist())
    .add_yaxis("1차유행 이후", del_seoul_top_af_count2[del_seoul_top_af_count2['목적지_시군구명']=='구로구']['수'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 평균 배달 요청 수 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='읍면동'),
                    yaxis_opts=opts.AxisOpts(name='배달 요청 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)


bar_count1 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='800px'))
    .add_xaxis(del_seoul_top_bef_count2[del_seoul_top_bef_count2['목적지_시군구명']=='금천구']['목적지_읍면동명'].unique().tolist())
    .add_yaxis("1차유행 이전", del_seoul_top_bef_count2[del_seoul_top_bef_count2['목적지_시군구명']=='금천구']['수'].tolist())
    .add_yaxis("1차유행 이후", del_seoul_top_af_count2[del_seoul_top_af_count2['목적지_시군구명']=='금천구']['수'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 평균 배달 요청 수 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='읍면동'),
                    yaxis_opts=opts.AxisOpts(name='배달 요청 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

bar_count2 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='1600px'))
    .add_xaxis(del_seoul_top_bef_count2[del_seoul_top_bef_count2['목적지_시군구명']=='영등포구']['목적지_읍면동명'].unique().tolist())
    .add_yaxis("1차유행 이전", del_seoul_top_bef_count2[del_seoul_top_bef_count2['목적지_시군구명']=='영등포구']['수'].tolist())
    .add_yaxis("1차유행 이후", del_seoul_top_af_count2[del_seoul_top_af_count2['목적지_시군구명']=='영등포구']['수'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 평균 배달 요청 수 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='읍면동'),
                    yaxis_opts=opts.AxisOpts(name='배달 요청 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_left='30%', legend_icon='pin'))
)

del_seoul_gk_tab_1.add(bar_count, "구로구")
del_seoul_gk_tab_1.add(bar_count1, "금천구")
del_seoul_gk_tab_1.add(bar_count2, "영등포구")

# %%
del_seoul_gk_tab_2 = Tab()

# 1차유행 이전/이후 배달 요청 수(경기) + 읍면동

bar_count3 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='800px'))
    .add_xaxis(del_gk_top_bef_count2[del_gk_top_bef_count2['목적지_시군구명']=='의정부시']['목적지_읍면동명'].unique().tolist())
    .add_yaxis("1차유행 이전", del_gk_top_bef_count2[del_gk_top_bef_count2['목적지_시군구명']=='의정부시']['수'].tolist())
    .add_yaxis("1차유행 이후", del_gk_top_af_count2[del_gk_top_af_count2['목적지_시군구명']=='의정부시']['수'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 배달 요청 수 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='읍면동'),
                    yaxis_opts=opts.AxisOpts(name='배달 요청 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)



bar_count4 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='1200px'))
    .add_xaxis(del_gk_top_bef_count2[del_gk_top_bef_count2['목적지_시군구명']=='부천시']['목적지_읍면동명'].unique().tolist())
    .add_yaxis("1차유행 이전", del_gk_top_bef_count2[del_gk_top_bef_count2['목적지_시군구명']=='부천시']['수'].tolist())
    .add_yaxis("1차유행 이후", del_gk_top_af_count2[del_gk_top_af_count2['목적지_시군구명']=='부천시']['수'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 배달 요청 수 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='읍면동'),
                    yaxis_opts=opts.AxisOpts(name='배달 요청 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_left='30%', legend_icon='pin'))
)

bar_count5 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='800px'))
    .add_xaxis(del_gk_top_bef_count2[del_gk_top_bef_count2['목적지_시군구명']=='광명시']['목적지_읍면동명'].unique().tolist())
    .add_yaxis("1차유행 이전", del_gk_top_bef_count2[del_gk_top_bef_count2['목적지_시군구명']=='광명시']['수'].tolist())
    .add_yaxis("1차유행 이후", del_gk_top_af_count2[del_gk_top_af_count2['목적지_시군구명']=='광명시']['수'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 배달 요청 수 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='읍면동'),
                    yaxis_opts=opts.AxisOpts(name='배달 요청 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

del_seoul_gk_tab_2.add(bar_count3, "의정부시")
del_seoul_gk_tab_2.add(bar_count4, "부천시")
del_seoul_gk_tab_2.add(bar_count5, "광명시")

# %%
# 일별 배달 요청수 변화
del_day_tab = Tab()

del_day = (Line(init_opts=opts.InitOpts(theme=ThemeType.SHINE, height='500px', width='800px'))
                   .add_xaxis(del_seoul_day[del_seoul_day['목적지_시군구명']=='구로구']['날짜'].astype(str).tolist())
                   .add_yaxis('구로구', del_seoul_day[del_seoul_day['목적지_시군구명']=='구로구']['수'].tolist())
                   .add_yaxis('금천구', del_seoul_day[del_seoul_day['목적지_시군구명']=='금천구']['수'].tolist())
                   .add_yaxis('영등포구', del_seoul_day[del_seoul_day['목적지_시군구명']=='영등포구']['수'].tolist())
                   .set_global_opts(title_opts=opts.TitleOpts(title='서울 일일 배달 요청 수'),
                                   xaxis_opts=opts.AxisOpts(name='날짜'),
                                   yaxis_opts=opts.AxisOpts(name='배달 요청 수', name_location="end"),
                                   tooltip_opts=opts.TooltipOpts(trigger='axis', axis_pointer_type='cross'),
                                   legend_opts=opts.LegendOpts(pos_top='5%', pos_right='20%', legend_icon='pin'))
)

del_day1 = (Line(init_opts=opts.InitOpts(theme=ThemeType.SHINE, height='500px', width='800px'))
                   .add_xaxis(del_gk_day[del_gk_day['목적지_시군구명']=='의정부시']['날짜'].astype(str).tolist())
                   .add_yaxis('의정부시', del_gk_day[del_gk_day['목적지_시군구명']=='의정부시']['수'].tolist())
                   .add_yaxis('부천시', del_gk_day[del_gk_day['목적지_시군구명']=='부천시']['수'].tolist())
                   .add_yaxis('광명시', del_gk_day[del_gk_day['목적지_시군구명']=='광명시']['수'].tolist())
                   .set_global_opts(title_opts=opts.TitleOpts(title='경기 일일 배달 요청 수'),
                                   xaxis_opts=opts.AxisOpts(name='날짜'),
                                   yaxis_opts=opts.AxisOpts(name='배달 요청 수', name_location="end"),
                                   tooltip_opts=opts.TooltipOpts(trigger='axis', axis_pointer_type='cross'),
                                   legend_opts=opts.LegendOpts(pos_top='5%', pos_right='20%', legend_icon='pin'))
)

del_day_tab.add(del_day, "서울")
del_day_tab.add(del_day1, "경기")

# %% [markdown]
# ### 야식/저녁 배달 비율

# %%
nd_ratio = Tab()

bar_nd = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='800px'))
    .add_xaxis(del_seoul_top_bef_nr.index.tolist())
    .add_yaxis("1차유행 이전", del_seoul_top_bef_nr.round(3).tolist())
    .add_yaxis("1차유행 이후", del_seoul_top_af_nr.round(3).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 야식비율변화"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='비율', name_location="start"))
)

bar_nd1 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='800px'))
    .add_xaxis(del_gk_top_bef_nr.index.tolist())
    .add_yaxis("1차유행 이전", del_gk_top_bef_nr.round(3).tolist())
    .add_yaxis("1차유행 이후", del_gk_top_af_nr.round(3).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 야식비율변화"),
                    xaxis_opts=opts.AxisOpts(name='시'),
                    yaxis_opts=opts.AxisOpts(name='비율', name_location="start"))
)

bar_nd2 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='800px'))
    .add_xaxis(del_seoul_top_bef_dinr.index.tolist())
    .add_yaxis("1차유행 이전", del_seoul_top_bef_dinr.round(3).tolist())
    .add_yaxis("1차유행 이후", del_seoul_top_af_dinr.round(3).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 저녁비율변화"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='비율', name_location="start"))
)

bar_nd3 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='800px'))
    .add_xaxis(del_gk_top_bef_dinr.index.tolist())
    .add_yaxis("1차유행 이전", del_gk_top_bef_dinr.round(3).tolist())
    .add_yaxis("1차유행 이후", del_gk_top_af_dinr.round(3).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 저녁비율변화"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='비율', name_location="start"))
)

nd_ratio.add(bar_nd, "서울(야식)")
nd_ratio.add(bar_nd1, "경기(야식)")
nd_ratio.add(bar_nd2, "서울(저녁)")
nd_ratio.add(bar_nd3, "경기(저녁)")

# %% [markdown]
# ### 인구 수(청장년층 비율)

# %%
# 청장년층 비율(읍면동(서울), 시별(경기))
region_ratio = Tab()

bar_ratio = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='1200px'))
    .add_xaxis(region_seoul_top_young[region_seoul_top_young['시군구명']=='구로구']['읍면동명'].unique().tolist())
    .add_yaxis("청장년층 인구비율", region_seoul_top_young[region_seoul_top_young['시군구명']=='구로구']['ratio'].round(3).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title='구로구 읍면동별 청장년층 비율'),
                    xaxis_opts=opts.AxisOpts(name='읍면동'),
                    yaxis_opts=opts.AxisOpts(name='비율', name_location="start"))
)

bar_ratio1 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='1200px'))
    .add_xaxis(region_seoul_top_young[region_seoul_top_young['시군구명']=='금천구']['읍면동명'].unique().tolist())
    .add_yaxis("청장년층 인구비율", region_seoul_top_young[region_seoul_top_young['시군구명']=='금천구']['ratio'].round(3).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title='금천구 읍면동별 청장년층 비율'),
                    xaxis_opts=opts.AxisOpts(name='읍면동'),
                    yaxis_opts=opts.AxisOpts(name='비율', name_location="start"))
)

bar_ratio2 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='1200px'))
    .add_xaxis(region_seoul_top_young[region_seoul_top_young['시군구명']=='영등포구']['읍면동명'].unique().tolist())
    .add_yaxis("청장년층 인구비율", region_seoul_top_young[region_seoul_top_young['시군구명']=='영등포구']['ratio'].round(3).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title='영등포구 읍면동별 청장년층 비율'),
                    xaxis_opts=opts.AxisOpts(name='읍면동'),
                    yaxis_opts=opts.AxisOpts(name='비율', name_location="start"))
)

bar_ratio3 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='800px'))
    .add_xaxis(region_gk_top_young['시군구명'].unique().tolist())
    .add_yaxis("청장년층 인구비율", region_gk_top_young['ratio'].round(3).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title='경기도 시별 청장년층 비율'),
                    xaxis_opts=opts.AxisOpts(name='읍면동'),
                    yaxis_opts=opts.AxisOpts(name='비율', name_location="start"))
)

region_ratio.add(bar_ratio, "구로구")
region_ratio.add(bar_ratio1, "금천구")
region_ratio.add(bar_ratio2, "영등포구")
region_ratio.add(bar_ratio3, "경기도")

# %%
# 청장년층 비율(구별(서울), 시별(경기))
region_ratio_1 = Tab()

bar_ratio4 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='600px'))
    .add_xaxis(region_seoul_ratio['시군구명'].unique().tolist())
    .add_yaxis("청장년층 인구비율", region_seoul_ratio['ratio'].round(3).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title='서울 구별 청장년층 비율'),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='비율', name_location="start"))
)

bar_ratio5 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='600px'))
    .add_xaxis(region_gk_top_young['시군구명'].unique().tolist())
    .add_yaxis("청장년층 인구비율", region_gk_top_young['ratio'].round(3).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title='경기도 시별 청장년층 비율'),
                    xaxis_opts=opts.AxisOpts(name='읍면동'),
                    yaxis_opts=opts.AxisOpts(name='비율', name_location="start"))
)

region_ratio_1.add(bar_ratio4, "서울")
region_ratio_1.add(bar_ratio5, "경기")

# %% [markdown]
# ### 배달 금액

# %%
del_seoul_gk_money = Tab()

# 1차유행 이전/이후 평균 배달 금액

bar2 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='750px'))
    .add_xaxis(del_seoul_money_bef['목적지_시군구명'].unique().tolist())
    .add_yaxis("1차유행 이전", del_seoul_money_bef['상품금액'].round(1).tolist())
    .add_yaxis("1차유행 이후", del_seoul_money_af['상품금액'].round(1).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 배달금액 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='상품금액', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

# 1차유행 이전/이후 평균 배달 금액(경기)

bar3 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='750px'))
    .add_xaxis(del_gk_money_bef['목적지_시군구명'].unique().tolist())
    .add_yaxis("1차유행 이전", del_gk_money_bef['상품금액'].round(1).tolist())
    .add_yaxis("1차유행 이후", del_gk_money_af['상품금액'].round(1).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 배달금액 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='상품금액', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

del_seoul_gk_money.add(bar2, "서울")
del_seoul_gk_money.add(bar3, "경기")

# %%
del_seoul_gk_money_1 = Tab()

# 1차유행 이전/이후 평균 배달 금액(서울, 읍면동별)

bar_money = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='750px'))
    .add_xaxis(del_seoul_money_bef_1[del_seoul_money_bef_1['목적지_시군구명']=='구로구']['목적지_읍면동명'].tolist())
    .add_yaxis("1차유행 이전", del_seoul_money_bef_1[del_seoul_money_bef_1['목적지_시군구명']=='구로구']['상품금액'].round(1).tolist())
    .add_yaxis("1차유행 이후", del_seoul_money_af_1[del_seoul_money_bef_1['목적지_시군구명']=='구로구']['상품금액'].round(1).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 배달금액 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='동'),
                    yaxis_opts=opts.AxisOpts(name='상품금액', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)


bar_money1 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='750px'))
    .add_xaxis(del_seoul_money_bef_1[del_seoul_money_bef_1['목적지_시군구명']=='금천구']['목적지_읍면동명'].tolist())
    .add_yaxis("1차유행 이전", del_seoul_money_bef_1[del_seoul_money_bef_1['목적지_시군구명']=='금천구']['상품금액'].round(1).tolist())
    .add_yaxis("1차유행 이후", del_seoul_money_af_1[del_seoul_money_bef_1['목적지_시군구명']=='금천구']['상품금액'].round(1).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 배달금액 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='동'),
                    yaxis_opts=opts.AxisOpts(name='상품금액', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

bar_money2 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='2000px'))
    .add_xaxis(del_seoul_money_bef_1[del_seoul_money_bef_1['목적지_시군구명']=='영등포구']['목적지_읍면동명'].tolist())
    .add_yaxis("1차유행 이전", del_seoul_money_bef_1[del_seoul_money_bef_1['목적지_시군구명']=='영등포구']['상품금액'].round(1).tolist())
    .add_yaxis("1차유행 이후", del_seoul_money_af_1[del_seoul_money_bef_1['목적지_시군구명']=='영등포구']['상품금액'].round(1).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 배달금액 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='동'),
                    yaxis_opts=opts.AxisOpts(name='상품금액', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

del_seoul_gk_money_1.add(bar_money, "구로구")
del_seoul_gk_money_1.add(bar_money1, "금천구")
del_seoul_gk_money_1.add(bar_money2, "영등포구")

# %% [markdown]
# ### 배달 업종

# %%
del_menu = Tab()

bar4 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='1400px'))
    .add_xaxis(del_seoul_menu_bef['업종명'].unique().tolist())
    .add_yaxis("1차 유행 이전",del_seoul_menu_bef[del_seoul_menu_bef['목적지_시군구명']=='구로구']['수'].tolist())
    .add_yaxis("1차 유행 이후",del_seoul_menu_af[del_seoul_menu_af['목적지_시군구명']=='구로구']['수'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 서울 배달업종 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='업종별 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

bar5 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='1400px'))
    .add_xaxis(del_seoul_menu_bef['업종명'].unique().tolist())
    .add_yaxis("1차 유행 이전",del_seoul_menu_bef[del_seoul_menu_bef['목적지_시군구명']=='금천구']['수'].tolist())
    .add_yaxis("1차 유행 이후",del_seoul_menu_af[del_seoul_menu_af['목적지_시군구명']=='금천구']['수'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 서울 배달업종 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='업종별 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

bar6 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='1400px'))
    .add_xaxis(del_seoul_menu_bef['업종명'].unique().tolist())
    .add_yaxis("1차 유행 이전",del_seoul_menu_bef[del_seoul_menu_bef['목적지_시군구명']=='영등포구']['수'].tolist())
    .add_yaxis("1차 유행 이후",del_seoul_menu_af[del_seoul_menu_af['목적지_시군구명']=='영등포구']['수'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 서울 배달업종 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='업종별 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

bar7 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='1400px'))
    .add_xaxis(del_gk_menu_bef['업종명'].unique().tolist())
    .add_yaxis("1차 유행 이전",del_gk_menu_bef[del_gk_menu_bef['목적지_시군구명']=='의정부시']['수'].tolist())
    .add_yaxis("1차 유행 이후",del_gk_menu_af[del_gk_menu_af['목적지_시군구명']=='의정부시']['수'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 경기 배달업종 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='업종별 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

bar8 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='1400px'))
    .add_xaxis(del_gk_menu_bef['업종명'].unique().tolist())
    .add_yaxis("1차 유행 이전",del_gk_menu_bef[del_gk_menu_bef['목적지_시군구명']=='부천시']['수'].tolist())
    .add_yaxis("1차 유행 이후",del_gk_menu_af[del_gk_menu_af['목적지_시군구명']=='부천시']['수'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 경기 배달업종 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='업종별 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

bar9 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='1400px'))
    .add_xaxis(del_gk_menu_bef['업종명'].unique().tolist())
    .add_yaxis("1차 유행 이전",del_gk_menu_bef[del_gk_menu_bef['목적지_시군구명']=='광명시']['수'].tolist())
    .add_yaxis("1차 유행 이후",del_gk_menu_af[del_gk_menu_af['목적지_시군구명']=='광명시']['수'].tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 경기 배달업종 변화",
                                              subtitle="20.02.29 전후"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='업종별 수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin'))
)

del_menu.add(bar4, "구로구")
del_menu.add(bar5, "금천구")
del_menu.add(bar6, "영등포구")
del_menu.add(bar7, "의정부시")
del_menu.add(bar8, "부천시")
del_menu.add(bar9, "광명시")

# %% [markdown]
# ### 배달 시간

# %%
# 전체기간
del_time = Tab()

bar_time = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA))
    .add_xaxis(del_seoul_top_com_mean['목적지_시군구명'].unique().tolist())
    .add_yaxis("평균 배달 시간", del_seoul_top_com_mean['배달시간'].round(1).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="서울 평균배달시간"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='배달시간', name_location='end'),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right="10%", legend_icon='pin'))
)

bar_time1 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA))
    .add_xaxis(del_gk_top_com_mean['목적지_시군구명'].unique().tolist())
    .add_yaxis("평균 배달 시간", del_gk_top_com_mean['배달시간'].round(1).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="경기 평균배달시간"),
                    xaxis_opts=opts.AxisOpts(name='시'),
                    yaxis_opts=opts.AxisOpts(name='배달시간', name_location='end'),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right="10%", legend_icon='pin'))
)

del_time.add(bar_time, "서울")
del_time.add(bar_time1, "경기")

# %%
# 1차유행 이전/이후
del_time_1 = Tab()

bar_time2 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA))
    .add_xaxis(del_seoul_top_com_mean_bef['목적지_시군구명'].unique().tolist())
    .add_yaxis("1차 유행 이전", del_seoul_top_com_mean_bef['배달시간'].round(1).tolist())
    .add_yaxis("1차 유행 이후", del_seoul_top_com_mean_af['배달시간'].round(1).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 이전/이후 평균배달시간"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='배달시간', name_location='end'),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right="10%", legend_icon='pin'))
)

bar_time3 = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA))
    .add_xaxis(del_gk_top_com_mean_bef['목적지_시군구명'].unique().tolist())
    .add_yaxis("1차 유행 이전", del_gk_top_com_mean_bef['배달시간'].round(1).tolist())
    .add_yaxis("1차 유행 이후", del_gk_top_com_mean_af['배달시간'].round(1).tolist())
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 이전/이후 평균배달시간"),
                    xaxis_opts=opts.AxisOpts(name='구'),
                    yaxis_opts=opts.AxisOpts(name='배달시간', name_location='end'),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right="10%", legend_icon='pin'))
)

del_time_1.add(bar_time2, "서울")
del_time_1.add(bar_time3, "경기")

# %% [markdown]
# ### 육체건강

# %%
health_tab = Tab()

health_year = (Line(init_opts=opts.InitOpts(theme=ThemeType.WESTEROS, height='500px', width='800px'))
                   .add_xaxis(bodyhealth[bodyhealth['지역']=='서울']['구분'].astype(str).tolist())
                   .add_yaxis('서울', bodyhealth[bodyhealth['지역']=='서울']['걷기 실천율'].tolist())
                   .add_yaxis('경기', bodyhealth[bodyhealth['지역']=='경기']['걷기 실천율'].tolist())
                   .add_yaxis('수도권', bodyhealth[bodyhealth['지역']=='수도권']['걷기 실천율'].tolist())
                   .add_yaxis('비수도권', bodyhealth[bodyhealth['지역']=='비수도권']['걷기 실천율'].tolist())
                   .set_global_opts(title_opts=opts.TitleOpts(title='지역별 걷기 실천율',
                                                              subtitle='최근 1주일, 1회 30분 이상, 1일 30분 이상 걷기, 주 5일 이상 실천'),
                                   xaxis_opts=opts.AxisOpts(name='연도'),
                                   yaxis_opts=opts.AxisOpts(),
                                   tooltip_opts=opts.TooltipOpts(trigger='axis', axis_pointer_type='cross'),
                                   legend_opts=opts.LegendOpts(pos_top='5%', pos_right='10%', legend_icon='pin'))
)

health_year1 = (Line(init_opts=opts.InitOpts(theme=ThemeType.WESTEROS, height='500px', width='800px'))
                   .add_xaxis(bodyhealth[bodyhealth['지역']=='서울']['구분'].astype(str).tolist())
                   .add_yaxis('서울', bodyhealth[bodyhealth['지역']=='서울']['건강생활실천율'].tolist())
                   .add_yaxis('경기', bodyhealth[bodyhealth['지역']=='경기']['건강생활실천율'].tolist())
                   .add_yaxis('수도권', bodyhealth[bodyhealth['지역']=='수도권']['건강생활실천율'].tolist())
                   .add_yaxis('비수도권', bodyhealth[bodyhealth['지역']=='비수도권']['건강생활실천율'].tolist())
                   .set_global_opts(title_opts=opts.TitleOpts(title='지역별 건강생활 실천율',
                                                              subtitle='금연, 절주, 걷기를 모두 실천하는 사람의 수의 비율'),
                                   xaxis_opts=opts.AxisOpts(name='연도'),
                                   yaxis_opts=opts.AxisOpts(),
                                   tooltip_opts=opts.TooltipOpts(trigger='axis', axis_pointer_type='cross'),
                                   legend_opts=opts.LegendOpts(pos_top='5%', pos_right='10%', legend_icon='pin'))
)

health_year2 = (Line(init_opts=opts.InitOpts(theme=ThemeType.WESTEROS, height='500px', width='800px'))
                   .add_xaxis(bodyhealth[bodyhealth['지역']=='서울']['구분'].astype(str).tolist())
                   .add_yaxis('서울', bodyhealth[bodyhealth['지역']=='서울']['비만율'].tolist())
                   .add_yaxis('경기', bodyhealth[bodyhealth['지역']=='경기']['비만율'].tolist())
                   .add_yaxis('수도권', bodyhealth[bodyhealth['지역']=='수도권']['비만율'].tolist())
                   .add_yaxis('비수도권', bodyhealth[bodyhealth['지역']=='비수도권']['비만율'].tolist())
                   .set_global_opts(title_opts=opts.TitleOpts(title='지역별 비만율',
                                                              subtitle='BMI 수치 25이상인 사람의 수의 비율'),
                                   xaxis_opts=opts.AxisOpts(name='연도'),
                                   yaxis_opts=opts.AxisOpts(),
                                   tooltip_opts=opts.TooltipOpts(trigger='axis', axis_pointer_type='cross'),
                                   legend_opts=opts.LegendOpts(pos_top='5%', pos_right='10%', legend_icon='pin'))
)

health_year3 = (Line(init_opts=opts.InitOpts(theme=ThemeType.WESTEROS, height='500px', width='800px'))
                   .add_xaxis(bodyhealth[bodyhealth['지역']=='서울']['구분'].astype(str).tolist())
                   .add_yaxis('서울', bodyhealth[bodyhealth['지역']=='서울']['체중조절시도율'].tolist())
                   .add_yaxis('경기', bodyhealth[bodyhealth['지역']=='경기']['체중조절시도율'].tolist())
                   .add_yaxis('수도권', bodyhealth[bodyhealth['지역']=='수도권']['체중조절시도율'].tolist())
                   .add_yaxis('비수도권', bodyhealth[bodyhealth['지역']=='비수도권']['체중조절시도율'].tolist())
                   .set_global_opts(title_opts=opts.TitleOpts(title='지역별 체중조절시도율',
                                                              subtitle='최근 1년간 체중 유지/감소 노력을 한 사람의 수의 비율'),
                                   xaxis_opts=opts.AxisOpts(name='연도'),
                                   yaxis_opts=opts.AxisOpts(),
                                   tooltip_opts=opts.TooltipOpts(trigger='axis', axis_pointer_type='cross'),
                                   legend_opts=opts.LegendOpts(pos_top='5%', pos_right='10%', legend_icon='pin'))
)

health_tab.add(health_year, "걷기 실천율")
health_tab.add(health_year1, "건강생활 실천율")
health_tab.add(health_year2, "비만율")
health_tab.add(health_year3, "체중조절시도율")

# %% [markdown]
# # **성현님**

# %% [markdown]
# **코로나 전후 업종별 배달 건수 변화**

# %%
fig_store_s = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='500px',width='1000px')
               
               ).add_xaxis(df_deliver_s_store['DLVR_STORE_INDUTY_NM'].unique().tolist()
                          
                          ).add_yaxis('코로나 이전',
                                      df_deliver_s_store[df_deliver_s_store['기간'] == '코로나 이전']['배달건수'].tolist(),
                                      stack="stack1"
                                
                          ).add_yaxis('코로나 이후',
                                      df_deliver_s_store[df_deliver_s_store['기간'] == '코로나 이후']['배달건수'].tolist(),
                                     stack="stack2"
                                      
                          ).set_global_opts(title_opts=opts.TitleOpts(title="서울특별시 코로나 전/후 업종별 배달 건수"),
                                            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top="5%", legend_icon ='pin'))
            
fig_store_g = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='500px',width='1000px')
               
               ).add_xaxis(df_deliver_g_store['DLVR_STORE_INDUTY_NM'].unique().tolist()
                          
                          ).add_yaxis('코로나 이전',
                                      df_deliver_g_store[df_deliver_g_store['기간'] == '코로나 이전']['배달건수'].tolist(),
                                      stack="stack1"
                                
                          ).add_yaxis('코로나 이후',
                                      df_deliver_g_store[df_deliver_g_store['기간'] == '코로나 이후']['배달건수'].tolist(),
                                     stack="stack2"
                                      
                          ).set_global_opts(title_opts=opts.TitleOpts(title="경기도 코로나 전/후 업종별 배달 건수"),
                                            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top="5%", legend_icon ='pin'))

fig_store = Page(layout=Page.SimplePageLayout)
fig_store.add(fig_store_s, fig_store_g)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#         <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/roma.js"></script>
#
#
# </head>
# <body>
#     <style>.box { justify-content:center; display:flex; flex-wrap:wrap;  }; </style>
#     <div class="box">
#                 <div id="7885525c12474ff2b2f66bea03cc1b2c" class="chart-container" style="width:1000px; height:500px;"></div>
#     <script>
#         var chart_7885525c12474ff2b2f66bea03cc1b2c = echarts.init(
#             document.getElementById('7885525c12474ff2b2f66bea03cc1b2c'), 'roma', {renderer: 'canvas'});
#         var option_7885525c12474ff2b2f66bea03cc1b2c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
# ...

# %% [markdown]
# **코로나 전후 지역별 배달 건수 변화**

# %%
fig_n_s = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='500px',width='1000px')
               
               ).add_xaxis(df_deliver_s_n.index.tolist()
                          
                          ).add_yaxis('코로나 이전',
                                      df_deliver_s_n['코로나 이전'].tolist(),
                                      stack="stack1"
                                
                          ).add_yaxis('코로나 이후',
                                      df_deliver_s_n['코로나 이후'].tolist(),
                                     stack="stack2"
                                      
                          ).set_global_opts(title_opts=opts.TitleOpts(title="서울특별시 배달량 상위 25% 시군구 코로나 전/후 배달 건수"),
                                            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top="8%", legend_icon ='pin'))

fig_n_g = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='500px',width='1000px')
               
               ).add_xaxis(df_deliver_g_n.index.tolist()
                          
                          ).add_yaxis('코로나 이전',
                                      df_deliver_g_n['코로나 이전'].tolist(),
                                      stack="stack1"
                                
                          ).add_yaxis('코로나 이후',
                                      df_deliver_g_n['코로나 이후'].tolist(),
                                     stack="stack2"
                                      
                          ).set_global_opts(title_opts=opts.TitleOpts(title="경기도 배달량 상위 25% 시군구 코로나 전/후 배달 건수"),
                                            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top="8%", legend_icon ='pin'))
            
fig_n_1 = Page(layout=Page.SimplePageLayout)
fig_n_1.add(fig_n_s, fig_n_g)

# %%
fig_n_s = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='300px',width='300px')
               
               ).add_xaxis(df_deliver_s_n.index.tolist()
                          
                          ).add_yaxis('',
                                      df_deliver_s_n['증가율'].tolist(),
                                      label_opts=opts.LabelOpts(formatter="{c}%")
                                      
                          ).set_global_opts(title_opts=opts.TitleOpts(title="서울특별시 배달 증가율"),
                                            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top="8%", legend_icon ='pin'))

fig_n_g = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='300px',width='500px')
               
               ).add_xaxis(df_deliver_g_n.index.tolist()
                          
                          ).add_yaxis('',
                                      df_deliver_g_n['증가율'].tolist(),
                                      label_opts=opts.LabelOpts(formatter="{c}%")
                                      
                          ).set_global_opts(title_opts=opts.TitleOpts(title="경기도 배달 증가율"),
                                            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top="8%", legend_icon ='pin'))
       
fig_n_2 = Page(layout=Page.SimplePageLayout)
fig_n_2.add(fig_n_s, fig_n_g)

# %% [markdown]
# **코로나 전후 주문 시간 변화**

# %%
fig_time_s = Line(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='500px',width='1000px')
               
               ).add_xaxis(df_deliver_s_time['배달 접수 시간'].unique().tolist()
                          
                          ).add_yaxis('코로나 이전',
                                      df_deliver_s_time[df_deliver_s_time['기간'] == '코로나 이전']['배달건수'].tolist(),
                                      stack="stack1"
                                
                          ).add_yaxis('코로나 이후',
                                      df_deliver_s_time[df_deliver_s_time['기간'] == '코로나 이후']['배달건수'].tolist(),
                                     stack="stack2"
                                      
                          ).set_global_opts(title_opts=opts.TitleOpts(title="서울특별시 코로나 전/후 배달시간대"),
                                            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top="5%", legend_icon ='pin'))
            
fig_time_g = Line(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='500px',width='1000px')
               
               ).add_xaxis(df_deliver_g_time['배달 접수 시간'].unique().tolist()
                          
                          ).add_yaxis('코로나 이전',
                                      df_deliver_g_time[df_deliver_g_time['기간'] == '코로나 이전']['배달건수'].tolist(),
                                      stack="stack1"
                                
                          ).add_yaxis('코로나 이후',
                                      df_deliver_g_time[df_deliver_g_time['기간'] == '코로나 이후']['배달건수'].tolist(),
                                     stack="stack2"
                                      
                          ).set_global_opts(title_opts=opts.TitleOpts(title="경기도 코로나 전/후 배달시간대"),
                                            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top="5%", legend_icon ='pin'))

fig_time = Page(layout=Page.SimplePageLayout)
fig_time.add(fig_time_s, fig_time_g)

# %% [markdown]
# **코로나 전후 주문 요일 변화**

# %%
fig_s_week =Timeline(init_opts=opts.InitOpts(theme=ThemeType.ROMA,height='500px', width='800px'))

for t in ['코로나 이전', '코로나 이후']:
    fig_s_week.add((Pie().add('', [z for z in zip(['월요일', '화요일', '수요일', '목요일','금요일', '토요일', '일요일'],
                                            df_deliver_s_week[df_deliver_s_week['기간'] == t]['배달건수'].tolist())],
                  label_opts=opts.LabelOpts(position='outside', formatter="{b}\n{d}%"),
                  radius=[70, 180]).set_global_opts(title_opts=opts.TitleOpts(title='서울특별시 코로나 전/후 배달요일'),
                                        legend_opts=opts.LegendOpts(type_ = 'scroll', pos_bottom ="60%",pos_right="3%",
                                                                    orient="vertical",legend_icon ='pin'))), t)

# %%
fig_g_week =Timeline(init_opts=opts.InitOpts(height='500px', width='800px'))

for t in ['코로나 이전', '코로나 이후']:
    fig_g_week.add((Pie().add('', [z for z in zip(['월요일', '화요일', '수요일', '목요일','금요일', '토요일', '일요일'],
                                            df_deliver_g_week[df_deliver_g_week['기간'] == t]['배달건수'].tolist())],
                  label_opts=opts.LabelOpts(position='outside', formatter="{b}\n{d}%"),
                  radius=[70, 180]).set_global_opts(title_opts=opts.TitleOpts(title='경기도 코로나 전/후 배달요일'),
                                        legend_opts=opts.LegendOpts(type_ = 'scroll', pos_bottom ="60%",pos_right="3%",
                                                                    orient="vertical",legend_icon ='pin'))), t)

# %% [markdown]
# **샐러드 판매점 개폐업**

# %%
x_data = ['서울시 개업','서울시 폐업','경기도 개업','경기도 폐업']
y_data_1 = [len(salad_seoul_open_bf),len(salad_seoul_closed_bf),len(salad_gyeong_open_bf),len(salad_gyeong_closed_bf)]
y_data_2 = [len(salad_seoul_open_af),len(salad_seoul_closed_af),len(salad_gyeong_open_af),len(salad_gyeong_closed_af)]

salad_bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px', width='800px'))
    .add_xaxis(x_data)
    .add_yaxis('1차유행 이전', y_data_1)
    .add_yaxis('1차유행 이후', y_data_2)
    .set_global_opts(title_opts=opts.TitleOpts(title="1차유행 전후 샐러드가게 개폐업 건수",
                                              subtitle="20.02.29 전후"),
                    
                    yaxis_opts=opts.AxisOpts(name='개업/폐업 신고수', name_location="start"),
                    legend_opts=opts.LegendOpts(pos_top="5%", pos_right='10%', legend_icon='pin')))

# %% [markdown]
# __듄넽_됣뀯_뗡뀱___됣뀿__■넧_믟뀴.ipynb

# %%
click = pd.read_csv('./DATA/조회수.csv')
click2 = pd.read_csv('./DATA/조회수_세부.csv')
trend = pd.read_csv('./DATA/통합검색.csv')

# %%
processed = pd.concat([ click2['date'], click2[click2.columns[1:5]] ], axis = 1)
drink = pd.concat([click2['date'], click2[click2.columns[5:9]]], axis = 1)
easycook = pd.concat([click2['date'], click2[click2.columns[9:12]]], axis = 1)
machine = pd.concat([click2['date'], click2[click2.columns[12:17]]], axis = 1)
kitchen = pd.concat([click2['date'], click2[click2.columns[17:]]], axis = 1)
#processed

# %%
easycook
# Out:
#            date       도시락   즉석국/즉석탕       샐러드
# 0    2019-01-01  24.87002  24.82547  22.11421
# 1    2019-01-02  39.73408  28.01451  32.88491
# 2    2019-01-03  34.89729  27.97581  28.64954
# 3    2019-01-04  26.37432  24.14026  23.38135
# 4    2019-01-05  19.38549  24.25151  19.84898
# ..          ...       ...       ...       ...
# 959  2021-08-17  66.03596  61.97178  64.91060
# 960  2021-08-18  60.97332  63.26642  59.98090
# 961  2021-08-19  54.87513  62.16364  54.65197
# 962  2021-08-20  42.20148  48.49173  42.90053
# 963  2021-08-21  36.75956  50.21362  38.92553
#
# [964 rows x 4 columns]

# %%
processed
# Out:
#            date        라면       즉석밥     간편조리식      쿠킹박스
# 0    2019-01-01  11.15720  23.37590  26.08977   3.10803
# 1    2019-01-02  14.36789  32.92228  32.22294   3.82367
# 2    2019-01-03  13.35161  29.64555  33.42977   3.65483
# 3    2019-01-04  12.12401  23.34810  29.06689   2.61448
# 4    2019-01-05  10.70136  19.57256  25.40830   2.32615
# ..          ...       ...       ...       ...       ...
# 959  2021-08-17  20.96667  45.16317  54.73407  23.43818
# 960  2021-08-18  20.99564  43.33903  56.65283  25.00844
# 961  2021-08-19  19.90374  39.16414  52.83816  24.72530
# 962  2021-08-20  17.41674  34.81663  46.23291  18.75211
# 963  2021-08-21  18.15669  36.04540  45.94357  20.27690
#
# [964 rows x 5 columns]

# %%
fig1 = px.line(processed, 
              x='date', 
              y=processed.columns[1:],  
             title='가공식품', width = 900, height = 600)

fig1.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-80aa642007f8> in <module>()
#       2               x='date',
#       3               y=processed.columns[1:],
# ----> 4              title='가공식품', width = 900, height = 600)
#       5
#       6 fig1.show()
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     212     a polyline mark in 2D space.
#     213     """
# ...

# %%
fig2 = px.line(drink, 
              x='date', 
              y=drink.columns[1:],  
             title='음료', width = 900, height = 500)
fig2.show()

# %%
fig3 = px.line(easycook, 
              x='date', 
              y=easycook.columns[1:],  
             title='간편조리', width = 900, height = 600)
fig3.show()

# %%
fig4 = px.line(machine, 
              x='date', 
              y=machine.columns[1:],  
             title='주방가전', width = 900, height = 600)
fig4.show()

# %%
fig5 = px.line(kitchen, 
              x='date', 
              y=kitchen.columns[1:],  
             title='주방용품', width = 900, height = 600)
fig5.show()

# %%
trend.head()

# %%
fig6 = px.line(trend, 
              x='date', 
              y=trend.columns[1:],  
             title='통합검색 조회수', width = 900, height = 600)
fig6.show()
# Out:
# <div>                            <div id="0484ee6a-3439-4cc8-8552-6d1821ca8da1" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0484ee6a-3439-4cc8-8552-6d1821ca8da1")) {                    Plotly.newPlot(                        "0484ee6a-3439-4cc8-8552-6d1821ca8da1",                        [{"hovertemplate":"variable=\ub2ed\uac00\uc2b4\uc0b4<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"\ub2ed\uac00\uc2b4\uc0b4","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\ub2ed\uac00\uc2b4\uc0b4","showlegend":true,"type":"scattergl","x":["2019-01-01","2019-01-02","2019-01-03","2019-01-04","2019-01-05","2019-01-06","2019-01-07","2019-01-08","2019-01-09","2019-01-10","2019-01-11","2019-01-12","2019-01-13"
# ...

# %% [markdown]
# # **4-2 정신건강**

# %%
df_psy = pd.read_csv("./DATA/정신건강지수.csv")

# %%
df_psy['연도'] = df_psy['연도'].astype(str)

# %%
df_psy.head()
# Out:
#      연도  스트레스 인지율  우울감 경험률  지역 시군구
# 0  2008      28.3      7.7  전국  전체
# 1  2009      27.2      6.9  전국  전체
# 2  2010      27.3      5.0  전국  전체
# 3  2011      27.9      4.6  전국  전체
# 4  2012      27.9      4.7  전국  전체

# %%
df_psy_t = df_psy[df_psy['시군구'] == '전체']

# %%
fig_psy_tab = Tab()

fig_stress = Line(init_opts=opts.InitOpts(theme=ThemeType.SHINE, height='500px',width='1000px')
               
               ).add_xaxis(df_psy_t['연도'].unique().tolist()
                          
                          ).add_yaxis('전국',
                                      df_psy_t[df_psy_t['지역'] == '전국']['스트레스 인지율'].tolist(),
                                      stack="stack1"
                                
                          ).add_yaxis('서울특별시',
                                      df_psy_t[df_psy_t['지역'] == '서울']['스트레스 인지율'].tolist(),
                                     stack="stack2"
                        
                          ).add_yaxis('경기도',
                                      df_psy_t[df_psy_t['지역'] == '경기']['스트레스 인지율'].tolist(),
                                     stack="stack3"
                                      
                          ).set_global_opts(title_opts=opts.TitleOpts(title="스트레스 인지율 변화"),
                                            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
                                            yaxis_opts=opts.AxisOpts(name='(%)', min_=20, name_location = "start"),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top="5%", legend_icon ='pin'))

fig_dep = Line(init_opts=opts.InitOpts(theme=ThemeType.SHINE, height='500px',width='1000px')
               
               ).add_xaxis(df_psy_t['연도'].unique().tolist()
                          
                          ).add_yaxis('전국',
                                      df_psy_t[df_psy_t['지역'] == '전국']['우울감 경험률'].tolist(),
                                      stack="stack1"
                                
                          ).add_yaxis('서울특별시',
                                      df_psy_t[df_psy_t['지역'] == '서울']['우울감 경험률'].tolist(),
                                     stack="stack2"
                        
                          ).add_yaxis('경기도',
                                      df_psy_t[df_psy_t['지역'] == '경기']['우울감 경험률'].tolist(),
                                     stack="stack3"
                                      
                          ).set_global_opts(title_opts=opts.TitleOpts(title="우울감 경험률 변화"),
                                            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30)),
                                            yaxis_opts=opts.AxisOpts(name='(%)', name_location = "start"),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top="5%", legend_icon ='pin'))


fig_psy_tab.add(fig_stress,'스트레스 인지율 변화')
fig_psy_tab.add(fig_dep,'우울감 경험률 변화')

# %%
df_psy_p = df_psy[(df_psy['시군구'] == '구로구') | (df_psy['시군구'] == '금천구')|
                  (df_psy['시군구'] == '영등포구') | (df_psy['시군구'] == '관악구')]

# %%
fig_psy_2_tab = Tab()

fig_stress_2 = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px',width='800px')
               
               ).add_xaxis(df_psy_p['시군구'].unique().tolist()
                          
                          ).add_yaxis('2018년',
                                      df_psy_p[df_psy_p['연도'] == '2018']['스트레스 인지율'].tolist(),
                                      stack="stack1"
                                
                          ).add_yaxis('2019년',
                                      df_psy_p[df_psy_p['연도'] == '2019']['스트레스 인지율'].tolist(),
                                     stack="stack2"
                        
                          ).add_yaxis('2020년',
                                      df_psy_p[df_psy_p['연도'] == '2020']['스트레스 인지율'].tolist(),
                                     stack="stack3"
                                              
                          ).set_global_opts(title_opts=opts.TitleOpts(title="서울특별시 시군구 스트레스 인지율 변화"),
                                            yaxis_opts=opts.AxisOpts(name='(%)', name_location = "start"),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top='20%', pos_left="90%", legend_icon ='pin'))

fig_dep_2 = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px',width='800px')
               
               ).add_xaxis(df_psy_p['시군구'].unique().tolist()
                          
                          ).add_yaxis('2018년',
                                      df_psy_p[df_psy_p['연도'] == '2018']['우울감 경험률'].tolist(),
                                      stack="stack1"
                                
                          ).add_yaxis('2019년',
                                      df_psy_p[df_psy_p['연도'] == '2019']['우울감 경험률'].tolist(),
                                     stack="stack2"
                        
                          ).add_yaxis('2020년',
                                      df_psy_p[df_psy_p['연도'] == '2020']['우울감 경험률'].tolist(),
                                     stack="stack3"
                                              
                          ).set_global_opts(title_opts=opts.TitleOpts(title="서울특별시 시군구 우울감 경험률 변화"),
                                            yaxis_opts=opts.AxisOpts(name='(%)', name_location = "start"),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top='20%', pos_left="90%", legend_icon ='pin'))

fig_psy_2_tab.add(fig_stress_2,'스트레스 인지율 변화')
fig_psy_2_tab.add(fig_dep_2,'우울감 경험률 변화')

# %%
df_psy_p_2 = df_psy[(df_psy['시군구'] == '의정부시') | (df_psy['시군구'] == '부천시') | (df_psy['시군구'] == '평택시')]

# %%
fig_psy_3_tab = Tab()

fig_stress_3 = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px',width='800px')
               
               ).add_xaxis(df_psy_p_2['시군구'].unique().tolist()
                          
                          ).add_yaxis('2018년',
                                      df_psy_p_2[df_psy_p_2['연도'] == '2018']['스트레스 인지율'].tolist(),
                                      stack="stack1"
                                
                          ).add_yaxis('2019년',
                                      df_psy_p_2[df_psy_p_2['연도'] == '2019']['스트레스 인지율'].tolist(),
                                     stack="stack2"
                        
                          ).add_yaxis('2020년',
                                      df_psy_p_2[df_psy_p_2['연도'] == '2020']['스트레스 인지율'].tolist(),
                                     stack="stack3"
                                              
                          ).set_global_opts(title_opts=opts.TitleOpts(title="경기도 시군구 스트레스 인지율 변화"),
                                            yaxis_opts=opts.AxisOpts(name='(%)', name_location = "start"),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top='20%', pos_left="90%", legend_icon ='pin'))

fig_dep_3 = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA, height='400px',width='800px')
               
               ).add_xaxis(df_psy_p_2['시군구'].unique().tolist()
                          
                          ).add_yaxis('2018년',
                                      df_psy_p_2[df_psy_p_2['연도'] == '2018']['우울감 경험률'].tolist(),
                                      stack="stack1"
                                
                          ).add_yaxis('2019년',
                                      df_psy_p_2[df_psy_p_2['연도'] == '2019']['우울감 경험률'].tolist(),
                                     stack="stack2"
                        
                          ).add_yaxis('2020년',
                                      df_psy_p_2[df_psy_p_2['연도'] == '2020']['우울감 경험률'].tolist(),
                                     stack="stack3"
                                              
                          ).set_global_opts(title_opts=opts.TitleOpts(title="경기도 시군구 우울감 경험률 변화"),
                                            yaxis_opts=opts.AxisOpts(name='(%)', name_location = "start"),
                                            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
                                            legend_opts=opts.LegendOpts(pos_top='20%', pos_left="90%", legend_icon ='pin'))

fig_psy_3_tab.add(fig_stress_3,'스트레스 인지율 변화')
fig_psy_3_tab.add(fig_dep_3,'우울감 경험률 변화')

# %% [markdown]
# ## **크롤링 코드**

# %%
import urllib.request
from datetime import datetime, timedelta
import pandas as pd
import json

today = str(datetime.now().date()); today

# api token
client_id = "CIfvLTmgF4CXCFZXWmPw" 
client_secret = "5Cl_s9Mdcx"

# %% [markdown]
# ### 카테고리 조회수

# %%
def click(cat):
    body = { "startDate": '2019-01-01', 
        "endDate": today, 
        "timeUnit": "date", 
        "category": [cat],
        "device": "", 
        "gender": "", 
        "ages": [ ] 
       } 
    body = json.dumps(body, ensure_ascii=False)
    url = "https://openapi.naver.com/v1/datalab/shopping/categories"
    requested = urllib.request.Request(url)
    requested.add_header("X-Naver-Client-Id", client_id)
    requested.add_header("X-Naver-Client-Secret", client_secret)
    requested.add_header("Content-Type", "application/json")
    response = urllib.request.urlopen(requested, data=body.encode("utf-8"))
    rescode = response.getcode()

    if(rescode==200):
        response_body = response.read()
        output_data = response_body.decode('utf-8')
    else:
        print('Error code:'+ rescode)
        
    result = json.loads(output_data)
    
    date = [a['period'] for a in result['results'][0]['data']]
    col = [a['ratio'] for a in result['results'][0]['data']]
    
    df = pd.DataFrame(
        {'date': date, 
         '{}'.format(cat['name']): col }
    )
    df.set_index('date', inplace = True)
    df.index = pd.to_datetime(df.index)
    return df

# %%
# 변수 
meat = {"name": "축산", "param": ["50000145"]}
fish = {"name": "수산", "param": ["50000159"]}
produce = {"name": "농산물", "param": ["50000160"]}
banchan = {"name": "반찬", "param": ["50000146"]}
kimchi = {"name": "김치", "param": ["50000147"]}
drink = {"name": "음료", "param": ["50000148"]}
snack = {"name": "과자", "param": ["50000149"]}
icecream = {"name": "아이스크림/빙수", "param": ["50000025"]}
processed = {"name": "가공식품", "param": ["50000150"]}
frozen = {"name": "냉동/간편조리식품", "param": ["50000026"]}
vitamin = {"name": "건강식품", "param": ["50000023"]}
diet = {"name": "다이어트식품", "param": ["50000024"]}
liquor = {"name": "전통주", "param": ["50006349"]}

living = {"name": "생활가전", "param": ["50000210"]}
kitchen = {"name": "주방가전", "param": ["50000213"]}
health = {"name": "헬스", "param": ["50000030"]}
cooking = {"name": "주방용품", "param": ["50000061"]}

# %%
# 상위 카테고리 더 세부적으로 (건강식품은 결이 다르다고 판단하여 제외)

#가공식품
ramen = {"name": "라면", "param": ["50001083"]}
rice = {"name": "즉석밥", "param": ["50001891"]}
easycook = {"name": "간편조리식", "param": ["50001894"]}
mealbox = {"name": "쿠킹박스", "param": ["50006808"]}
baking = {"name": "제과/제빵재료", "param": ["50001895"]}

#음료
coffee = {"name": "커피", "param": ["50001081"]}
bean = {"name": "원두/생두", "param": ["50002266"]}
capsule = {"name": "캡슐커피", "param": ["50009600"]}

#냉동/간편
lunchbox = {"name": "도시락", "param": ["50006199"]}
soup = {"name": "즉석국/즉석탕", "param": ["50001876"]}
salad = {"name": "샐러드", "param": ["50001873"]}

#주방가전
waffle = {"name": "와플제조기", "param": ["50001724"]}
airfry = {"name": "에어프라이어", "param": ["50007072"]}
baker = {"name": "제빵기", "param": ["50001710"]}
brew = {"name": "커피머신", "param": ["50001185"]}
waste = {"name": "음식물처리기", "param": ["50001707"]}

#주방용품
tumbler = {"name": "텀블러", "param": ["50004540"]}
cofstuff = {"name": "커피용품", "param": ["50000891"]}
bakestuff = {"name": "제과/제빵용품", "param": ["50000893"]}

#다이어트

# %%
click = pd.concat([click(meat), click(fish), click(produce), click(banchan), 
           click(kimchi), click(drink), click(snack), click(icecream),
           click(processed), click(frozen), click(vitamin), click(diet), click(liquor), 
           click(living), click(kitchen), click(health), click(cooking)], 
          axis = 1)

# %%
click2 = pd.concat([click(ramen), click(rice), click(easycook), click(mealbox), click(baking), 
                    click(coffee), click(bean), click(capsule),
                    click(lunchbox), click(soup), click(salad), 
                    click(waffle), click(airfry), click(baker), click(brew), click(waste), 
                    click(tumbler), click(cofstuff), click(bakestuff)], axis = 1)

# %%
click2.fillna(0, inplace = True)
click2.head()
# Out:
#                   라면       즉석밥     간편조리식     쿠킹박스   제과/제빵재료        커피  \
# date
# 2019-01-01  11.15720  23.37590  26.08977  3.10803  22.51941  40.22793
# 2019-01-02  14.36789  32.92228  32.22294  3.82367  27.60266  50.55990
# 2019-01-03  13.35161  29.64555  33.42977  3.65483  26.74262  45.82578
# 2019-01-04  12.12401  23.34810  29.06689  2.61448  25.38547  40.42883
# 2019-01-05  10.70136  19.57256  25.40830  2.32615  21.67696  37.58525
#
#                원두/생두  캡슐커피       도시락   즉석국/즉석탕       샐러드    와플제조기  에어프라이어  \
# date
# 2019-01-01  22.96843   0.0  24.87002  24.82547  22.11421  8.66186     0.0
# 2019-01-02  25.87624   0.0  39.73408  28.01451  32.88491  8.96382     0.0
# 2019-01-03  24.65067   0.0  34.89729  27.97581  28.64954  8.68087     0.0
# 2019-01-04  21.97704   0.0  26.37432  24.14026  23.38135  9.24045     0.0
# 2019-01-05  22.35174   0.0  19.38549  24.25151  19.84898  8.55628     0.0
#
#                  제빵기      커피머신   음식물처리기       텀블러      커피용품   제과/제빵용품
# date
# ...

# %%
click2.to_csv('조회수_세부.csv', encoding = 'utf-8-sig')

# %% [markdown]
# ### 통합 검색어 조회수

# %%
#검색어 트렌드
def trend(kw):
    url = "https://openapi.naver.com/v1/datalab/search";
    body = { "startDate": '2019-01-01', 
        "endDate": today, 
        "timeUnit": "date", 
        "keywordGroups": [kw],
        "device": "", 
        "gender": "", 
        "ages": [ ] 
       } 

    body = json.dumps(body, ensure_ascii=False)
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    request.add_header("Content-Type","application/json")
    response = urllib.request.urlopen(request, data=body.encode("utf-8"))
    rescode = response.getcode()
    
    if(rescode==200):
        response_body = response.read()
        output_data = response_body.decode('utf-8')
    else:
        print("Error Code:" + rescode)
    
    result = json.loads(output_data)
    
    date = [a['period'] for a in result['results'][0]['data']]
    col = [a['ratio'] for a in result['results'][0]['data']]
    
    df = pd.DataFrame(
        { 'date': date, 
         '{}'.format(kw['groupName']): col }
    )
    df.set_index('date', inplace = True)
    df.index = pd.to_datetime(df.index)
    
    return df

# %%
# 키워드 그룹
chicken = {"groupName": "닭가슴살", "keywords": ["닭가슴살", '닭찌', '닭찌찌']}
delivery = {"groupName": "배달", "keywords": ["배달", '배달의민족', '배민', '쿠팡이츠']}
exercise = {"groupName": "운동", "keywords": ["운동", '홈트', '홈트레이닝', '다이어트', '식단']}
restaurant = {"groupName": "맛집", "keywords": ['맛집', '맛집추천', '맛집방문', '맛집리뷰', '식당', '외식']}

# %%
df_trend = pd.concat([trend(chicken), trend(delivery), trend(exercise), trend(restaurant)], 
          axis = 1)
df_trend.head()
# Out:
#                 닭가슴살       배달        운동        맛집
# date
# 2019-01-01  26.50553  1.44487  23.43666  22.06973
# 2019-01-02  43.24106  1.06295  26.05993  11.89232
# 2019-01-03  39.85886  1.10159  22.02474  12.55841
# 2019-01-04  34.15847  1.16269  20.16998  13.26045
# 2019-01-05  27.01744  1.28542  18.43437  18.56801

# %%
df_trend.to_csv('통합검색.csv', encoding = 'utf-8-sig')

# %% [markdown]
# ### Appendix
#
# - 외부데이터
# https://stat.gg.go.kr/statgg/main.html (경기 인구 데이터, 경기통계자료)
# https://data.seoul.go.kr (서울 행정동 코드)
# 육체, 정신건강 관련 자료(2020 질병관리본부 지역사회건강조사)
